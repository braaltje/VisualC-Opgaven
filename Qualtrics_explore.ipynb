# %%
from pyspark.sql import SparkSession
import pandas as pd
import json
from pyspark.sql import functions as F
from pyspark.sql import types as T

spark = ( SparkSession.builder
         .config("spark.driver.memory", '8g')
         .getOrCreate()
)         
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-9VG9TAU:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# read data
df = spark.read.json("./data/SV_3TPNSvgX6GtUpuJ-Unzip/DowDirectRelationshipSurvey.json")
df.printSchema()
# Out:
# root
#  |-- responses: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- displayedFields: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- displayedValues: struct (nullable = true)
#  |    |    |    |-- QID10_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID10_2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID10_3: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID10_4: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID10_5: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID12: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID128: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID130_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID130_10: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID130_2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID130_3: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID130_4: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID130_6: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID130_7: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID130_8: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID130_9: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID133: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID137_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID137_2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID137_3: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID137_6: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID137_7: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID137_8: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID138: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID13_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID13_2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID13_4: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID13_5: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID13_6: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID13_8: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID144: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID145_1: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_2: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_3: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_5: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_9: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID146: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID149: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID15: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID16_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID16_2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID16_3: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID16_4: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID16_5: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID18: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID19_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID19_2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID19_3: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID21_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID21_2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID21_4: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID21_5: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID21_6: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID21_7: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID23: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID24_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID24_2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID24_4: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID24_5: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID27: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID28_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID28_2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID28_3: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID28_4: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID28_5: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID28_6: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID28_7: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID3: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID33: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID34: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID35_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID35_2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID35_3: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID35_4: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID35_6: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID35_7: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID35_9: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID37: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID38_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID38_3: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID38_5: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID4: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID40: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID41_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID41_3: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID41_4: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID41_5: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID41_7: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID41_8: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID42: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID47: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID48: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID5: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID7_1: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID7_2: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID7_4: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID7_5: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID7_6: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID7_8: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID9: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |-- QID94: array (nullable = true)
#  |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |-- labels: struct (nullable = true)
#  |    |    |    |-- QID101: string (nullable = true)
#  |    |    |    |-- QID103_1: string (nullable = true)
#  |    |    |    |-- QID103_2: string (nullable = true)
#  |    |    |    |-- QID103_3: string (nullable = true)
#  |    |    |    |-- QID103_4: string (nullable = true)
#  |    |    |    |-- QID103_5: string (nullable = true)
#  |    |    |    |-- QID103_6: string (nullable = true)
#  |    |    |    |-- QID103_7: string (nullable = true)
#  |    |    |    |-- QID103_8: string (nullable = true)
#  |    |    |    |-- QID103_9: string (nullable = true)
#  |    |    |    |-- QID106: string (nullable = true)
#  |    |    |    |-- QID107: string (nullable = true)
#  |    |    |    |-- QID108: string (nullable = true)
#  |    |    |    |-- QID10_1: string (nullable = true)
#  |    |    |    |-- QID10_2: string (nullable = true)
#  |    |    |    |-- QID10_3: string (nullable = true)
#  |    |    |    |-- QID10_4: string (nullable = true)
#  |    |    |    |-- QID10_5: string (nullable = true)
#  |    |    |    |-- QID10_6: string (nullable = true)
#  |    |    |    |-- QID119: string (nullable = true)
#  |    |    |    |-- QID12: string (nullable = true)
#  |    |    |    |-- QID120_1: string (nullable = true)
#  |    |    |    |-- QID120_2: string (nullable = true)
#  |    |    |    |-- QID120_3: string (nullable = true)
#  |    |    |    |-- QID120_4: string (nullable = true)
#  |    |    |    |-- QID120_5: string (nullable = true)
#  |    |    |    |-- QID120_6: string (nullable = true)
#  |    |    |    |-- QID120_7: string (nullable = true)
#  |    |    |    |-- QID120_8: string (nullable = true)
#  |    |    |    |-- QID128: string (nullable = true)
#  |    |    |    |-- QID130_1: string (nullable = true)
#  |    |    |    |-- QID130_10: string (nullable = true)
#  |    |    |    |-- QID130_2: string (nullable = true)
#  |    |    |    |-- QID130_3: string (nullable = true)
#  |    |    |    |-- QID130_4: string (nullable = true)
#  |    |    |    |-- QID130_6: string (nullable = true)
#  |    |    |    |-- QID130_7: string (nullable = true)
#  |    |    |    |-- QID130_8: string (nullable = true)
#  |    |    |    |-- QID130_9: string (nullable = true)
#  |    |    |    |-- QID133: string (nullable = true)
#  |    |    |    |-- QID135: string (nullable = true)
#  |    |    |    |-- QID137_1: string (nullable = true)
#  |    |    |    |-- QID137_2: string (nullable = true)
#  |    |    |    |-- QID137_3: string (nullable = true)
#  |    |    |    |-- QID137_4: string (nullable = true)
#  |    |    |    |-- QID137_5: string (nullable = true)
#  |    |    |    |-- QID137_6: string (nullable = true)
#  |    |    |    |-- QID137_7: string (nullable = true)
#  |    |    |    |-- QID137_8: string (nullable = true)
#  |    |    |    |-- QID138: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID13_1: string (nullable = true)
#  |    |    |    |-- QID13_2: string (nullable = true)
#  |    |    |    |-- QID13_3: string (nullable = true)
#  |    |    |    |-- QID13_4: string (nullable = true)
#  |    |    |    |-- QID13_5: string (nullable = true)
#  |    |    |    |-- QID13_6: string (nullable = true)
#  |    |    |    |-- QID13_7: string (nullable = true)
#  |    |    |    |-- QID13_8: string (nullable = true)
#  |    |    |    |-- QID144: string (nullable = true)
#  |    |    |    |-- QID145_1: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_2: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_3: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_5: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_9: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID146: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID149: string (nullable = true)
#  |    |    |    |-- QID15: string (nullable = true)
#  |    |    |    |-- QID16_1: string (nullable = true)
#  |    |    |    |-- QID16_2: string (nullable = true)
#  |    |    |    |-- QID16_3: string (nullable = true)
#  |    |    |    |-- QID16_4: string (nullable = true)
#  |    |    |    |-- QID16_5: string (nullable = true)
#  |    |    |    |-- QID18: string (nullable = true)
#  |    |    |    |-- QID19_1: string (nullable = true)
#  |    |    |    |-- QID19_2: string (nullable = true)
#  |    |    |    |-- QID19_3: string (nullable = true)
#  |    |    |    |-- QID2: string (nullable = true)
#  |    |    |    |-- QID21_1: string (nullable = true)
#  |    |    |    |-- QID21_2: string (nullable = true)
#  |    |    |    |-- QID21_3: string (nullable = true)
#  |    |    |    |-- QID21_4: string (nullable = true)
#  |    |    |    |-- QID21_5: string (nullable = true)
#  |    |    |    |-- QID21_6: string (nullable = true)
#  |    |    |    |-- QID21_7: string (nullable = true)
#  |    |    |    |-- QID23: string (nullable = true)
#  |    |    |    |-- QID24_1: string (nullable = true)
#  |    |    |    |-- QID24_2: string (nullable = true)
#  |    |    |    |-- QID24_3: string (nullable = true)
#  |    |    |    |-- QID24_4: string (nullable = true)
#  |    |    |    |-- QID24_5: string (nullable = true)
#  |    |    |    |-- QID27: string (nullable = true)
#  |    |    |    |-- QID28_1: string (nullable = true)
#  |    |    |    |-- QID28_2: string (nullable = true)
#  |    |    |    |-- QID28_3: string (nullable = true)
#  |    |    |    |-- QID28_4: string (nullable = true)
#  |    |    |    |-- QID28_5: string (nullable = true)
#  |    |    |    |-- QID28_6: string (nullable = true)
#  |    |    |    |-- QID28_7: string (nullable = true)
#  |    |    |    |-- QID28_8: string (nullable = true)
#  |    |    |    |-- QID3: string (nullable = true)
#  |    |    |    |-- QID33: string (nullable = true)
#  |    |    |    |-- QID34: string (nullable = true)
#  |    |    |    |-- QID35_1: string (nullable = true)
#  |    |    |    |-- QID35_2: string (nullable = true)
#  |    |    |    |-- QID35_3: string (nullable = true)
#  |    |    |    |-- QID35_4: string (nullable = true)
#  |    |    |    |-- QID35_5: string (nullable = true)
#  |    |    |    |-- QID35_6: string (nullable = true)
#  |    |    |    |-- QID35_7: string (nullable = true)
#  |    |    |    |-- QID35_9: string (nullable = true)
#  |    |    |    |-- QID37: string (nullable = true)
#  |    |    |    |-- QID38_1: string (nullable = true)
#  |    |    |    |-- QID38_2: string (nullable = true)
#  |    |    |    |-- QID38_3: string (nullable = true)
#  |    |    |    |-- QID38_5: string (nullable = true)
#  |    |    |    |-- QID4: string (nullable = true)
#  |    |    |    |-- QID40: string (nullable = true)
#  |    |    |    |-- QID41_1: string (nullable = true)
#  |    |    |    |-- QID41_2: string (nullable = true)
#  |    |    |    |-- QID41_3: string (nullable = true)
#  |    |    |    |-- QID41_4: string (nullable = true)
#  |    |    |    |-- QID41_5: string (nullable = true)
#  |    |    |    |-- QID41_6: string (nullable = true)
#  |    |    |    |-- QID41_7: string (nullable = true)
#  |    |    |    |-- QID41_8: string (nullable = true)
#  |    |    |    |-- QID42: string (nullable = true)
#  |    |    |    |-- QID47: string (nullable = true)
#  |    |    |    |-- QID48: string (nullable = true)
#  |    |    |    |-- QID5: string (nullable = true)
#  |    |    |    |-- QID7_1: string (nullable = true)
#  |    |    |    |-- QID7_2: string (nullable = true)
#  |    |    |    |-- QID7_3: string (nullable = true)
#  |    |    |    |-- QID7_4: string (nullable = true)
#  |    |    |    |-- QID7_5: string (nullable = true)
#  |    |    |    |-- QID7_6: string (nullable = true)
#  |    |    |    |-- QID7_7: string (nullable = true)
#  |    |    |    |-- QID7_8: string (nullable = true)
#  |    |    |    |-- QID9: string (nullable = true)
#  |    |    |    |-- QID94: string (nullable = true)
#  |    |    |    |-- finished: string (nullable = true)
#  |    |    |    |-- status: string (nullable = true)
#  |    |    |-- responseId: string (nullable = true)
#  |    |    |-- values: struct (nullable = true)
#  |    |    |    |-- AccountName: string (nullable = true)
#  |    |    |    |-- AccountName_5e02b1554bfe4b0dac61f801SenPol: long (nullable = true)
#  |    |    |    |-- AccountName_5e02b1554bfe4b0dac61f801SenScore: long (nullable = true)
#  |    |    |    |-- BPCode: string (nullable = true)
#  |    |    |    |-- COVIDComments: string (nullable = true)
#  |    |    |    |-- CRMLink: string (nullable = true)
#  |    |    |    |-- CRMOwner: string (nullable = true)
#  |    |    |    |-- CRMOwnerEmail: string (nullable = true)
#  |    |    |    |-- ContactArea: string (nullable = true)
#  |    |    |    |-- ContactAreaCode: string (nullable = true)
#  |    |    |    |-- ContactCountry: string (nullable = true)
#  |    |    |    |-- ContactCountryCode: string (nullable = true)
#  |    |    |    |-- ContactEmail: string (nullable = true)
#  |    |    |    |-- ContactName: string (nullable = true)
#  |    |    |    |-- CustomerType: string (nullable = true)
#  |    |    |    |-- Digital: string (nullable = true)
#  |    |    |    |-- Distinction: string (nullable = true)
#  |    |    |    |-- GlobalCode: string (nullable = true)
#  |    |    |    |-- GlobalName: string (nullable = true)
#  |    |    |    |-- Guide: string (nullable = true)
#  |    |    |    |-- LST: string (nullable = true)
#  |    |    |    |-- OwnerArea: string (nullable = true)
#  |    |    |    |-- OwnerAreaCode: string (nullable = true)
#  |    |    |    |-- OwnerCountry: string (nullable = true)
#  |    |    |    |-- OwnerCountryCode: string (nullable = true)
#  |    |    |    |-- PrimaryBusiness: string (nullable = true)
#  |    |    |    |-- PrimaryBusinessGroup: string (nullable = true)
#  |    |    |    |-- PrimaryMajorMarket: string (nullable = true)
#  |    |    |    |-- QID101: long (nullable = true)
#  |    |    |    |-- QID103_1: long (nullable = true)
#  |    |    |    |-- QID103_2: long (nullable = true)
#  |    |    |    |-- QID103_3: long (nullable = true)
#  |    |    |    |-- QID103_4: long (nullable = true)
#  |    |    |    |-- QID103_5: long (nullable = true)
#  |    |    |    |-- QID103_6: long (nullable = true)
#  |    |    |    |-- QID103_7: long (nullable = true)
#  |    |    |    |-- QID103_8: long (nullable = true)
#  |    |    |    |-- QID103_9: long (nullable = true)
#  |    |    |    |-- QID105_TEXT: string (nullable = true)
#  |    |    |    |-- QID106: long (nullable = true)
#  |    |    |    |-- QID107: long (nullable = true)
#  |    |    |    |-- QID108: long (nullable = true)
#  |    |    |    |-- QID10_1: long (nullable = true)
#  |    |    |    |-- QID10_2: long (nullable = true)
#  |    |    |    |-- QID10_3: long (nullable = true)
#  |    |    |    |-- QID10_4: long (nullable = true)
#  |    |    |    |-- QID10_5: long (nullable = true)
#  |    |    |    |-- QID10_6: long (nullable = true)
#  |    |    |    |-- QID119: long (nullable = true)
#  |    |    |    |-- QID11_TEXT: string (nullable = true)
#  |    |    |    |-- QID11_TEXT_TRANSLATEDen93ihhyq: string (nullable = true)
#  |    |    |    |-- QID12: long (nullable = true)
#  |    |    |    |-- QID120_1: long (nullable = true)
#  |    |    |    |-- QID120_2: long (nullable = true)
#  |    |    |    |-- QID120_3: long (nullable = true)
#  |    |    |    |-- QID120_4: long (nullable = true)
#  |    |    |    |-- QID120_5: long (nullable = true)
#  |    |    |    |-- QID120_6: long (nullable = true)
#  |    |    |    |-- QID120_7: long (nullable = true)
#  |    |    |    |-- QID120_8: long (nullable = true)
#  |    |    |    |-- QID121_TEXT: string (nullable = true)
#  |    |    |    |-- QID128: long (nullable = true)
#  |    |    |    |-- QID130_1: long (nullable = true)
#  |    |    |    |-- QID130_10: long (nullable = true)
#  |    |    |    |-- QID130_2: long (nullable = true)
#  |    |    |    |-- QID130_3: long (nullable = true)
#  |    |    |    |-- QID130_4: long (nullable = true)
#  |    |    |    |-- QID130_6: long (nullable = true)
#  |    |    |    |-- QID130_7: long (nullable = true)
#  |    |    |    |-- QID130_8: long (nullable = true)
#  |    |    |    |-- QID130_9: long (nullable = true)
#  |    |    |    |-- QID131_TEXT: string (nullable = true)
#  |    |    |    |-- QID131_TEXT_TRANSLATEDenn363j8m: string (nullable = true)
#  |    |    |    |-- QID133: long (nullable = true)
#  |    |    |    |-- QID135: long (nullable = true)
#  |    |    |    |-- QID135_3_TEXT: string (nullable = true)
#  |    |    |    |-- QID135_3_TEXT_TRANSLATEDen8wvxb4h: string (nullable = true)
#  |    |    |    |-- QID137_1: long (nullable = true)
#  |    |    |    |-- QID137_2: long (nullable = true)
#  |    |    |    |-- QID137_3: long (nullable = true)
#  |    |    |    |-- QID137_4: long (nullable = true)
#  |    |    |    |-- QID137_5: long (nullable = true)
#  |    |    |    |-- QID137_6: long (nullable = true)
#  |    |    |    |-- QID137_7: long (nullable = true)
#  |    |    |    |-- QID137_8: long (nullable = true)
#  |    |    |    |-- QID138: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID139_TEXT: string (nullable = true)
#  |    |    |    |-- QID139_TEXT_TRANSLATEDen8qtubni: string (nullable = true)
#  |    |    |    |-- QID13_1: long (nullable = true)
#  |    |    |    |-- QID13_2: long (nullable = true)
#  |    |    |    |-- QID13_3: long (nullable = true)
#  |    |    |    |-- QID13_4: long (nullable = true)
#  |    |    |    |-- QID13_5: long (nullable = true)
#  |    |    |    |-- QID13_6: long (nullable = true)
#  |    |    |    |-- QID13_7: long (nullable = true)
#  |    |    |    |-- QID13_8: long (nullable = true)
#  |    |    |    |-- QID142_BROWSER: string (nullable = true)
#  |    |    |    |-- QID142_OS: string (nullable = true)
#  |    |    |    |-- QID142_RESOLUTION: string (nullable = true)
#  |    |    |    |-- QID142_VERSION: string (nullable = true)
#  |    |    |    |-- QID143_9_TEXT_TRANSLATEDenqvga6ad: string (nullable = true)
#  |    |    |    |-- QID144: long (nullable = true)
#  |    |    |    |-- QID145_1: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_2: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_3: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_5: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_9: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_9_TEXT: string (nullable = true)
#  |    |    |    |-- QID145_9_TEXT_TRANSLATEDen5op1zyu: string (nullable = true)
#  |    |    |    |-- QID146: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID146_9_TEXT: string (nullable = true)
#  |    |    |    |-- QID146_9_TEXT_TRANSLATEDenl7jzo6e: string (nullable = true)
#  |    |    |    |-- QID149: long (nullable = true)
#  |    |    |    |-- QID14_TEXT: string (nullable = true)
#  |    |    |    |-- QID14_TEXT_5e02b1554bfe4b0dac61f801SenPol: long (nullable = true)
#  |    |    |    |-- QID14_TEXT_5e02b1554bfe4b0dac61f801SenScore: long (nullable = true)
#  |    |    |    |-- QID14_TEXT_TRANSLATEDenwohlzuj: string (nullable = true)
#  |    |    |    |-- QID15: long (nullable = true)
#  |    |    |    |-- QID16_1: long (nullable = true)
#  |    |    |    |-- QID16_2: long (nullable = true)
#  |    |    |    |-- QID16_3: long (nullable = true)
#  |    |    |    |-- QID16_4: long (nullable = true)
#  |    |    |    |-- QID16_5: long (nullable = true)
#  |    |    |    |-- QID17_TEXT: string (nullable = true)
#  |    |    |    |-- QID17_TEXT_TRANSLATEDenre9rccw: string (nullable = true)
#  |    |    |    |-- QID18: long (nullable = true)
#  |    |    |    |-- QID19_1: long (nullable = true)
#  |    |    |    |-- QID19_2: long (nullable = true)
#  |    |    |    |-- QID19_3: long (nullable = true)
#  |    |    |    |-- QID2: long (nullable = true)
#  |    |    |    |-- QID20_TEXT: string (nullable = true)
#  |    |    |    |-- QID20_TEXT_TRANSLATEDen1ao9nhu: string (nullable = true)
#  |    |    |    |-- QID21_1: long (nullable = true)
#  |    |    |    |-- QID21_2: long (nullable = true)
#  |    |    |    |-- QID21_3: long (nullable = true)
#  |    |    |    |-- QID21_4: long (nullable = true)
#  |    |    |    |-- QID21_5: long (nullable = true)
#  |    |    |    |-- QID21_6: long (nullable = true)
#  |    |    |    |-- QID21_7: long (nullable = true)
#  |    |    |    |-- QID22_TEXT: string (nullable = true)
#  |    |    |    |-- QID22_TEXT_TRANSLATEDens1qb5u1: string (nullable = true)
#  |    |    |    |-- QID23: long (nullable = true)
#  |    |    |    |-- QID24_1: long (nullable = true)
#  |    |    |    |-- QID24_2: long (nullable = true)
#  |    |    |    |-- QID24_3: long (nullable = true)
#  |    |    |    |-- QID24_4: long (nullable = true)
#  |    |    |    |-- QID24_5: long (nullable = true)
#  |    |    |    |-- QID25_TEXT: string (nullable = true)
#  |    |    |    |-- QID25_TEXT_TRANSLATEDenly9xu00: string (nullable = true)
#  |    |    |    |-- QID27: long (nullable = true)
#  |    |    |    |-- QID28_1: long (nullable = true)
#  |    |    |    |-- QID28_2: long (nullable = true)
#  |    |    |    |-- QID28_3: long (nullable = true)
#  |    |    |    |-- QID28_4: long (nullable = true)
#  |    |    |    |-- QID28_5: long (nullable = true)
#  |    |    |    |-- QID28_6: long (nullable = true)
#  |    |    |    |-- QID28_7: long (nullable = true)
#  |    |    |    |-- QID28_8: long (nullable = true)
#  |    |    |    |-- QID29_TEXT: string (nullable = true)
#  |    |    |    |-- QID29_TEXT_TRANSLATEDenwvw39mf: string (nullable = true)
#  |    |    |    |-- QID2_5_TEXT: string (nullable = true)
#  |    |    |    |-- QID2_5_TEXT_TRANSLATEDenekufezj: string (nullable = true)
#  |    |    |    |-- QID3: long (nullable = true)
#  |    |    |    |-- QID33: long (nullable = true)
#  |    |    |    |-- QID34: long (nullable = true)
#  |    |    |    |-- QID35_1: long (nullable = true)
#  |    |    |    |-- QID35_2: long (nullable = true)
#  |    |    |    |-- QID35_3: long (nullable = true)
#  |    |    |    |-- QID35_4: long (nullable = true)
#  |    |    |    |-- QID35_5: long (nullable = true)
#  |    |    |    |-- QID35_6: long (nullable = true)
#  |    |    |    |-- QID35_7: long (nullable = true)
#  |    |    |    |-- QID35_9: long (nullable = true)
#  |    |    |    |-- QID36_TEXT: string (nullable = true)
#  |    |    |    |-- QID36_TEXT_TRANSLATEDen6kfua67: string (nullable = true)
#  |    |    |    |-- QID37: long (nullable = true)
#  |    |    |    |-- QID38_1: long (nullable = true)
#  |    |    |    |-- QID38_2: long (nullable = true)
#  |    |    |    |-- QID38_3: long (nullable = true)
#  |    |    |    |-- QID38_5: long (nullable = true)
#  |    |    |    |-- QID39_TEXT: string (nullable = true)
#  |    |    |    |-- QID39_TEXT_TRANSLATEDeni4c8ssx: string (nullable = true)
#  |    |    |    |-- QID4: long (nullable = true)
#  |    |    |    |-- QID40: long (nullable = true)
#  |    |    |    |-- QID41_1: long (nullable = true)
#  |    |    |    |-- QID41_2: long (nullable = true)
#  |    |    |    |-- QID41_3: long (nullable = true)
#  |    |    |    |-- QID41_4: long (nullable = true)
#  |    |    |    |-- QID41_5: long (nullable = true)
#  |    |    |    |-- QID41_6: long (nullable = true)
#  |    |    |    |-- QID41_7: long (nullable = true)
#  |    |    |    |-- QID41_8: long (nullable = true)
#  |    |    |    |-- QID42: long (nullable = true)
#  |    |    |    |-- QID43_TEXT: string (nullable = true)
#  |    |    |    |-- QID43_TEXT_TRANSLATEDenu8vx5gc: string (nullable = true)
#  |    |    |    |-- QID44_TEXT: string (nullable = true)
#  |    |    |    |-- QID44_TEXT_TRANSLATEDen6m3495e: string (nullable = true)
#  |    |    |    |-- QID47: long (nullable = true)
#  |    |    |    |-- QID48: long (nullable = true)
#  |    |    |    |-- QID49_TEXT: string (nullable = true)
#  |    |    |    |-- QID49_TEXT_TRANSLATEDeni0zgv8j: string (nullable = true)
#  |    |    |    |-- QID5: long (nullable = true)
#  |    |    |    |-- QID50_TEXT: string (nullable = true)
#  |    |    |    |-- QID50_TEXT_TRANSLATEDen10pb0wp: string (nullable = true)
#  |    |    |    |-- QID6_TEXT: string (nullable = true)
#  |    |    |    |-- QID6_TEXT_TRANSLATEDena6a9kkj: string (nullable = true)
#  |    |    |    |-- QID7_1: long (nullable = true)
#  |    |    |    |-- QID7_2: long (nullable = true)
#  |    |    |    |-- QID7_3: long (nullable = true)
#  |    |    |    |-- QID7_4: long (nullable = true)
#  |    |    |    |-- QID7_5: long (nullable = true)
#  |    |    |    |-- QID7_6: long (nullable = true)
#  |    |    |    |-- QID7_7: long (nullable = true)
#  |    |    |    |-- QID7_8: long (nullable = true)
#  |    |    |    |-- QID8_TEXT: string (nullable = true)
#  |    |    |    |-- QID8_TEXT_TRANSLATEDenue1spzz: string (nullable = true)
#  |    |    |    |-- QID9: long (nullable = true)
#  |    |    |    |-- QID94: long (nullable = true)
#  |    |    |    |-- Q_Language: string (nullable = true)
#  |    |    |    |-- Quarter: string (nullable = true)
#  |    |    |    |-- QuarterRollup: string (nullable = true)
#  |    |    |    |-- QuarterYear: string (nullable = true)
#  |    |    |    |-- Randomized_ID: string (nullable = true)
#  |    |    |    |-- Region: string (nullable = true)
#  |    |    |    |-- SalName: string (nullable = true)
#  |    |    |    |-- Score: string (nullable = true)
#  |    |    |    |-- SellerEmail: string (nullable = true)
#  |    |    |    |-- SellerEmailSSO: string (nullable = true)
#  |    |    |    |-- SellerName: string (nullable = true)
#  |    |    |    |-- StrategicName: string (nullable = true)
#  |    |    |    |-- Submit: string (nullable = true)
#  |    |    |    |-- SustainabilityLanguageFilter: string (nullable = true)
#  |    |    |    |-- Year: string (nullable = true)
#  |    |    |    |-- _recordId: string (nullable = true)
#  |    |    |    |-- distributionChannel: string (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- endDate: string (nullable = true)
#  |    |    |    |-- finished: long (nullable = true)
#  |    |    |    |-- ipAddress: string (nullable = true)
#  |    |    |    |-- locationLatitude: string (nullable = true)
#  |    |    |    |-- locationLongitude: string (nullable = true)
#  |    |    |    |-- progress: long (nullable = true)
#  |    |    |    |-- recipientEmail: string (nullable = true)
#  |    |    |    |-- recipientFirstName: string (nullable = true)
#  |    |    |    |-- recipientLastName: string (nullable = true)
#  |    |    |    |-- recordedDate: string (nullable = true)
#  |    |    |    |-- startDate: string (nullable = true)
#  |    |    |    |-- status: long (nullable = true)
#  |    |    |    |-- userLanguage: string (nullable = true)

# %%
# Use 'transform' to keep only the required fields in the 'responses' array
df = df.withColumn(
    "responses",
    F.expr("""
        transform(
            responses,
            r -> struct(
                r.responseId as responseId,
                r.values as values,
                r.labels as labels
            )
        )
    """)
)

# Show the updated schema to confirm the fields
df.printSchema()
# Out:
# root
#  |-- responses: array (nullable = true)
#  |    |-- element: struct (containsNull = false)
#  |    |    |-- responseId: string (nullable = true)
#  |    |    |-- values: struct (nullable = true)
#  |    |    |    |-- AccountName: string (nullable = true)
#  |    |    |    |-- AccountName_5e02b1554bfe4b0dac61f801SenPol: long (nullable = true)
#  |    |    |    |-- AccountName_5e02b1554bfe4b0dac61f801SenScore: long (nullable = true)
#  |    |    |    |-- BPCode: string (nullable = true)
#  |    |    |    |-- COVIDComments: string (nullable = true)
#  |    |    |    |-- CRMLink: string (nullable = true)
#  |    |    |    |-- CRMOwner: string (nullable = true)
#  |    |    |    |-- CRMOwnerEmail: string (nullable = true)
#  |    |    |    |-- ContactArea: string (nullable = true)
#  |    |    |    |-- ContactAreaCode: string (nullable = true)
#  |    |    |    |-- ContactCountry: string (nullable = true)
#  |    |    |    |-- ContactCountryCode: string (nullable = true)
#  |    |    |    |-- ContactEmail: string (nullable = true)
#  |    |    |    |-- ContactName: string (nullable = true)
#  |    |    |    |-- CustomerType: string (nullable = true)
#  |    |    |    |-- Digital: string (nullable = true)
#  |    |    |    |-- Distinction: string (nullable = true)
#  |    |    |    |-- GlobalCode: string (nullable = true)
#  |    |    |    |-- GlobalName: string (nullable = true)
#  |    |    |    |-- Guide: string (nullable = true)
#  |    |    |    |-- LST: string (nullable = true)
#  |    |    |    |-- OwnerArea: string (nullable = true)
#  |    |    |    |-- OwnerAreaCode: string (nullable = true)
#  |    |    |    |-- OwnerCountry: string (nullable = true)
#  |    |    |    |-- OwnerCountryCode: string (nullable = true)
#  |    |    |    |-- PrimaryBusiness: string (nullable = true)
#  |    |    |    |-- PrimaryBusinessGroup: string (nullable = true)
#  |    |    |    |-- PrimaryMajorMarket: string (nullable = true)
#  |    |    |    |-- QID101: long (nullable = true)
#  |    |    |    |-- QID103_1: long (nullable = true)
#  |    |    |    |-- QID103_2: long (nullable = true)
#  |    |    |    |-- QID103_3: long (nullable = true)
#  |    |    |    |-- QID103_4: long (nullable = true)
#  |    |    |    |-- QID103_5: long (nullable = true)
#  |    |    |    |-- QID103_6: long (nullable = true)
#  |    |    |    |-- QID103_7: long (nullable = true)
#  |    |    |    |-- QID103_8: long (nullable = true)
#  |    |    |    |-- QID103_9: long (nullable = true)
#  |    |    |    |-- QID105_TEXT: string (nullable = true)
#  |    |    |    |-- QID106: long (nullable = true)
#  |    |    |    |-- QID107: long (nullable = true)
#  |    |    |    |-- QID108: long (nullable = true)
#  |    |    |    |-- QID10_1: long (nullable = true)
#  |    |    |    |-- QID10_2: long (nullable = true)
#  |    |    |    |-- QID10_3: long (nullable = true)
#  |    |    |    |-- QID10_4: long (nullable = true)
#  |    |    |    |-- QID10_5: long (nullable = true)
#  |    |    |    |-- QID10_6: long (nullable = true)
#  |    |    |    |-- QID119: long (nullable = true)
#  |    |    |    |-- QID11_TEXT: string (nullable = true)
#  |    |    |    |-- QID11_TEXT_TRANSLATEDen93ihhyq: string (nullable = true)
#  |    |    |    |-- QID12: long (nullable = true)
#  |    |    |    |-- QID120_1: long (nullable = true)
#  |    |    |    |-- QID120_2: long (nullable = true)
#  |    |    |    |-- QID120_3: long (nullable = true)
#  |    |    |    |-- QID120_4: long (nullable = true)
#  |    |    |    |-- QID120_5: long (nullable = true)
#  |    |    |    |-- QID120_6: long (nullable = true)
#  |    |    |    |-- QID120_7: long (nullable = true)
#  |    |    |    |-- QID120_8: long (nullable = true)
#  |    |    |    |-- QID121_TEXT: string (nullable = true)
#  |    |    |    |-- QID128: long (nullable = true)
#  |    |    |    |-- QID130_1: long (nullable = true)
#  |    |    |    |-- QID130_10: long (nullable = true)
#  |    |    |    |-- QID130_2: long (nullable = true)
#  |    |    |    |-- QID130_3: long (nullable = true)
#  |    |    |    |-- QID130_4: long (nullable = true)
#  |    |    |    |-- QID130_6: long (nullable = true)
#  |    |    |    |-- QID130_7: long (nullable = true)
#  |    |    |    |-- QID130_8: long (nullable = true)
#  |    |    |    |-- QID130_9: long (nullable = true)
#  |    |    |    |-- QID131_TEXT: string (nullable = true)
#  |    |    |    |-- QID131_TEXT_TRANSLATEDenn363j8m: string (nullable = true)
#  |    |    |    |-- QID133: long (nullable = true)
#  |    |    |    |-- QID135: long (nullable = true)
#  |    |    |    |-- QID135_3_TEXT: string (nullable = true)
#  |    |    |    |-- QID135_3_TEXT_TRANSLATEDen8wvxb4h: string (nullable = true)
#  |    |    |    |-- QID137_1: long (nullable = true)
#  |    |    |    |-- QID137_2: long (nullable = true)
#  |    |    |    |-- QID137_3: long (nullable = true)
#  |    |    |    |-- QID137_4: long (nullable = true)
#  |    |    |    |-- QID137_5: long (nullable = true)
#  |    |    |    |-- QID137_6: long (nullable = true)
#  |    |    |    |-- QID137_7: long (nullable = true)
#  |    |    |    |-- QID137_8: long (nullable = true)
#  |    |    |    |-- QID138: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID139_TEXT: string (nullable = true)
#  |    |    |    |-- QID139_TEXT_TRANSLATEDen8qtubni: string (nullable = true)
#  |    |    |    |-- QID13_1: long (nullable = true)
#  |    |    |    |-- QID13_2: long (nullable = true)
#  |    |    |    |-- QID13_3: long (nullable = true)
#  |    |    |    |-- QID13_4: long (nullable = true)
#  |    |    |    |-- QID13_5: long (nullable = true)
#  |    |    |    |-- QID13_6: long (nullable = true)
#  |    |    |    |-- QID13_7: long (nullable = true)
#  |    |    |    |-- QID13_8: long (nullable = true)
#  |    |    |    |-- QID142_BROWSER: string (nullable = true)
#  |    |    |    |-- QID142_OS: string (nullable = true)
#  |    |    |    |-- QID142_RESOLUTION: string (nullable = true)
#  |    |    |    |-- QID142_VERSION: string (nullable = true)
#  |    |    |    |-- QID143_9_TEXT_TRANSLATEDenqvga6ad: string (nullable = true)
#  |    |    |    |-- QID144: long (nullable = true)
#  |    |    |    |-- QID145_1: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_2: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_3: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_5: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_9: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_9_TEXT: string (nullable = true)
#  |    |    |    |-- QID145_9_TEXT_TRANSLATEDen5op1zyu: string (nullable = true)
#  |    |    |    |-- QID146: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID146_9_TEXT: string (nullable = true)
#  |    |    |    |-- QID146_9_TEXT_TRANSLATEDenl7jzo6e: string (nullable = true)
#  |    |    |    |-- QID149: long (nullable = true)
#  |    |    |    |-- QID14_TEXT: string (nullable = true)
#  |    |    |    |-- QID14_TEXT_5e02b1554bfe4b0dac61f801SenPol: long (nullable = true)
#  |    |    |    |-- QID14_TEXT_5e02b1554bfe4b0dac61f801SenScore: long (nullable = true)
#  |    |    |    |-- QID14_TEXT_TRANSLATEDenwohlzuj: string (nullable = true)
#  |    |    |    |-- QID15: long (nullable = true)
#  |    |    |    |-- QID16_1: long (nullable = true)
#  |    |    |    |-- QID16_2: long (nullable = true)
#  |    |    |    |-- QID16_3: long (nullable = true)
#  |    |    |    |-- QID16_4: long (nullable = true)
#  |    |    |    |-- QID16_5: long (nullable = true)
#  |    |    |    |-- QID17_TEXT: string (nullable = true)
#  |    |    |    |-- QID17_TEXT_TRANSLATEDenre9rccw: string (nullable = true)
#  |    |    |    |-- QID18: long (nullable = true)
#  |    |    |    |-- QID19_1: long (nullable = true)
#  |    |    |    |-- QID19_2: long (nullable = true)
#  |    |    |    |-- QID19_3: long (nullable = true)
#  |    |    |    |-- QID2: long (nullable = true)
#  |    |    |    |-- QID20_TEXT: string (nullable = true)
#  |    |    |    |-- QID20_TEXT_TRANSLATEDen1ao9nhu: string (nullable = true)
#  |    |    |    |-- QID21_1: long (nullable = true)
#  |    |    |    |-- QID21_2: long (nullable = true)
#  |    |    |    |-- QID21_3: long (nullable = true)
#  |    |    |    |-- QID21_4: long (nullable = true)
#  |    |    |    |-- QID21_5: long (nullable = true)
#  |    |    |    |-- QID21_6: long (nullable = true)
#  |    |    |    |-- QID21_7: long (nullable = true)
#  |    |    |    |-- QID22_TEXT: string (nullable = true)
#  |    |    |    |-- QID22_TEXT_TRANSLATEDens1qb5u1: string (nullable = true)
#  |    |    |    |-- QID23: long (nullable = true)
#  |    |    |    |-- QID24_1: long (nullable = true)
#  |    |    |    |-- QID24_2: long (nullable = true)
#  |    |    |    |-- QID24_3: long (nullable = true)
#  |    |    |    |-- QID24_4: long (nullable = true)
#  |    |    |    |-- QID24_5: long (nullable = true)
#  |    |    |    |-- QID25_TEXT: string (nullable = true)
#  |    |    |    |-- QID25_TEXT_TRANSLATEDenly9xu00: string (nullable = true)
#  |    |    |    |-- QID27: long (nullable = true)
#  |    |    |    |-- QID28_1: long (nullable = true)
#  |    |    |    |-- QID28_2: long (nullable = true)
#  |    |    |    |-- QID28_3: long (nullable = true)
#  |    |    |    |-- QID28_4: long (nullable = true)
#  |    |    |    |-- QID28_5: long (nullable = true)
#  |    |    |    |-- QID28_6: long (nullable = true)
#  |    |    |    |-- QID28_7: long (nullable = true)
#  |    |    |    |-- QID28_8: long (nullable = true)
#  |    |    |    |-- QID29_TEXT: string (nullable = true)
#  |    |    |    |-- QID29_TEXT_TRANSLATEDenwvw39mf: string (nullable = true)
#  |    |    |    |-- QID2_5_TEXT: string (nullable = true)
#  |    |    |    |-- QID2_5_TEXT_TRANSLATEDenekufezj: string (nullable = true)
#  |    |    |    |-- QID3: long (nullable = true)
#  |    |    |    |-- QID33: long (nullable = true)
#  |    |    |    |-- QID34: long (nullable = true)
#  |    |    |    |-- QID35_1: long (nullable = true)
#  |    |    |    |-- QID35_2: long (nullable = true)
#  |    |    |    |-- QID35_3: long (nullable = true)
#  |    |    |    |-- QID35_4: long (nullable = true)
#  |    |    |    |-- QID35_5: long (nullable = true)
#  |    |    |    |-- QID35_6: long (nullable = true)
#  |    |    |    |-- QID35_7: long (nullable = true)
#  |    |    |    |-- QID35_9: long (nullable = true)
#  |    |    |    |-- QID36_TEXT: string (nullable = true)
#  |    |    |    |-- QID36_TEXT_TRANSLATEDen6kfua67: string (nullable = true)
#  |    |    |    |-- QID37: long (nullable = true)
#  |    |    |    |-- QID38_1: long (nullable = true)
#  |    |    |    |-- QID38_2: long (nullable = true)
#  |    |    |    |-- QID38_3: long (nullable = true)
#  |    |    |    |-- QID38_5: long (nullable = true)
#  |    |    |    |-- QID39_TEXT: string (nullable = true)
#  |    |    |    |-- QID39_TEXT_TRANSLATEDeni4c8ssx: string (nullable = true)
#  |    |    |    |-- QID4: long (nullable = true)
#  |    |    |    |-- QID40: long (nullable = true)
#  |    |    |    |-- QID41_1: long (nullable = true)
#  |    |    |    |-- QID41_2: long (nullable = true)
#  |    |    |    |-- QID41_3: long (nullable = true)
#  |    |    |    |-- QID41_4: long (nullable = true)
#  |    |    |    |-- QID41_5: long (nullable = true)
#  |    |    |    |-- QID41_6: long (nullable = true)
#  |    |    |    |-- QID41_7: long (nullable = true)
#  |    |    |    |-- QID41_8: long (nullable = true)
#  |    |    |    |-- QID42: long (nullable = true)
#  |    |    |    |-- QID43_TEXT: string (nullable = true)
#  |    |    |    |-- QID43_TEXT_TRANSLATEDenu8vx5gc: string (nullable = true)
#  |    |    |    |-- QID44_TEXT: string (nullable = true)
#  |    |    |    |-- QID44_TEXT_TRANSLATEDen6m3495e: string (nullable = true)
#  |    |    |    |-- QID47: long (nullable = true)
#  |    |    |    |-- QID48: long (nullable = true)
#  |    |    |    |-- QID49_TEXT: string (nullable = true)
#  |    |    |    |-- QID49_TEXT_TRANSLATEDeni0zgv8j: string (nullable = true)
#  |    |    |    |-- QID5: long (nullable = true)
#  |    |    |    |-- QID50_TEXT: string (nullable = true)
#  |    |    |    |-- QID50_TEXT_TRANSLATEDen10pb0wp: string (nullable = true)
#  |    |    |    |-- QID6_TEXT: string (nullable = true)
#  |    |    |    |-- QID6_TEXT_TRANSLATEDena6a9kkj: string (nullable = true)
#  |    |    |    |-- QID7_1: long (nullable = true)
#  |    |    |    |-- QID7_2: long (nullable = true)
#  |    |    |    |-- QID7_3: long (nullable = true)
#  |    |    |    |-- QID7_4: long (nullable = true)
#  |    |    |    |-- QID7_5: long (nullable = true)
#  |    |    |    |-- QID7_6: long (nullable = true)
#  |    |    |    |-- QID7_7: long (nullable = true)
#  |    |    |    |-- QID7_8: long (nullable = true)
#  |    |    |    |-- QID8_TEXT: string (nullable = true)
#  |    |    |    |-- QID8_TEXT_TRANSLATEDenue1spzz: string (nullable = true)
#  |    |    |    |-- QID9: long (nullable = true)
#  |    |    |    |-- QID94: long (nullable = true)
#  |    |    |    |-- Q_Language: string (nullable = true)
#  |    |    |    |-- Quarter: string (nullable = true)
#  |    |    |    |-- QuarterRollup: string (nullable = true)
#  |    |    |    |-- QuarterYear: string (nullable = true)
#  |    |    |    |-- Randomized_ID: string (nullable = true)
#  |    |    |    |-- Region: string (nullable = true)
#  |    |    |    |-- SalName: string (nullable = true)
#  |    |    |    |-- Score: string (nullable = true)
#  |    |    |    |-- SellerEmail: string (nullable = true)
#  |    |    |    |-- SellerEmailSSO: string (nullable = true)
#  |    |    |    |-- SellerName: string (nullable = true)
#  |    |    |    |-- StrategicName: string (nullable = true)
#  |    |    |    |-- Submit: string (nullable = true)
#  |    |    |    |-- SustainabilityLanguageFilter: string (nullable = true)
#  |    |    |    |-- Year: string (nullable = true)
#  |    |    |    |-- _recordId: string (nullable = true)
#  |    |    |    |-- distributionChannel: string (nullable = true)
#  |    |    |    |-- duration: long (nullable = true)
#  |    |    |    |-- endDate: string (nullable = true)
#  |    |    |    |-- finished: long (nullable = true)
#  |    |    |    |-- ipAddress: string (nullable = true)
#  |    |    |    |-- locationLatitude: string (nullable = true)
#  |    |    |    |-- locationLongitude: string (nullable = true)
#  |    |    |    |-- progress: long (nullable = true)
#  |    |    |    |-- recipientEmail: string (nullable = true)
#  |    |    |    |-- recipientFirstName: string (nullable = true)
#  |    |    |    |-- recipientLastName: string (nullable = true)
#  |    |    |    |-- recordedDate: string (nullable = true)
#  |    |    |    |-- startDate: string (nullable = true)
#  |    |    |    |-- status: long (nullable = true)
#  |    |    |    |-- userLanguage: string (nullable = true)
#  |    |    |-- labels: struct (nullable = true)
#  |    |    |    |-- QID101: string (nullable = true)
#  |    |    |    |-- QID103_1: string (nullable = true)
#  |    |    |    |-- QID103_2: string (nullable = true)
#  |    |    |    |-- QID103_3: string (nullable = true)
#  |    |    |    |-- QID103_4: string (nullable = true)
#  |    |    |    |-- QID103_5: string (nullable = true)
#  |    |    |    |-- QID103_6: string (nullable = true)
#  |    |    |    |-- QID103_7: string (nullable = true)
#  |    |    |    |-- QID103_8: string (nullable = true)
#  |    |    |    |-- QID103_9: string (nullable = true)
#  |    |    |    |-- QID106: string (nullable = true)
#  |    |    |    |-- QID107: string (nullable = true)
#  |    |    |    |-- QID108: string (nullable = true)
#  |    |    |    |-- QID10_1: string (nullable = true)
#  |    |    |    |-- QID10_2: string (nullable = true)
#  |    |    |    |-- QID10_3: string (nullable = true)
#  |    |    |    |-- QID10_4: string (nullable = true)
#  |    |    |    |-- QID10_5: string (nullable = true)
#  |    |    |    |-- QID10_6: string (nullable = true)
#  |    |    |    |-- QID119: string (nullable = true)
#  |    |    |    |-- QID12: string (nullable = true)
#  |    |    |    |-- QID120_1: string (nullable = true)
#  |    |    |    |-- QID120_2: string (nullable = true)
#  |    |    |    |-- QID120_3: string (nullable = true)
#  |    |    |    |-- QID120_4: string (nullable = true)
#  |    |    |    |-- QID120_5: string (nullable = true)
#  |    |    |    |-- QID120_6: string (nullable = true)
#  |    |    |    |-- QID120_7: string (nullable = true)
#  |    |    |    |-- QID120_8: string (nullable = true)
#  |    |    |    |-- QID128: string (nullable = true)
#  |    |    |    |-- QID130_1: string (nullable = true)
#  |    |    |    |-- QID130_10: string (nullable = true)
#  |    |    |    |-- QID130_2: string (nullable = true)
#  |    |    |    |-- QID130_3: string (nullable = true)
#  |    |    |    |-- QID130_4: string (nullable = true)
#  |    |    |    |-- QID130_6: string (nullable = true)
#  |    |    |    |-- QID130_7: string (nullable = true)
#  |    |    |    |-- QID130_8: string (nullable = true)
#  |    |    |    |-- QID130_9: string (nullable = true)
#  |    |    |    |-- QID133: string (nullable = true)
#  |    |    |    |-- QID135: string (nullable = true)
#  |    |    |    |-- QID137_1: string (nullable = true)
#  |    |    |    |-- QID137_2: string (nullable = true)
#  |    |    |    |-- QID137_3: string (nullable = true)
#  |    |    |    |-- QID137_4: string (nullable = true)
#  |    |    |    |-- QID137_5: string (nullable = true)
#  |    |    |    |-- QID137_6: string (nullable = true)
#  |    |    |    |-- QID137_7: string (nullable = true)
#  |    |    |    |-- QID137_8: string (nullable = true)
#  |    |    |    |-- QID138: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID13_1: string (nullable = true)
#  |    |    |    |-- QID13_2: string (nullable = true)
#  |    |    |    |-- QID13_3: string (nullable = true)
#  |    |    |    |-- QID13_4: string (nullable = true)
#  |    |    |    |-- QID13_5: string (nullable = true)
#  |    |    |    |-- QID13_6: string (nullable = true)
#  |    |    |    |-- QID13_7: string (nullable = true)
#  |    |    |    |-- QID13_8: string (nullable = true)
#  |    |    |    |-- QID144: string (nullable = true)
#  |    |    |    |-- QID145_1: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_2: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_3: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_5: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID145_9: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID146: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- QID149: string (nullable = true)
#  |    |    |    |-- QID15: string (nullable = true)
#  |    |    |    |-- QID16_1: string (nullable = true)
#  |    |    |    |-- QID16_2: string (nullable = true)
#  |    |    |    |-- QID16_3: string (nullable = true)
#  |    |    |    |-- QID16_4: string (nullable = true)
#  |    |    |    |-- QID16_5: string (nullable = true)
#  |    |    |    |-- QID18: string (nullable = true)
#  |    |    |    |-- QID19_1: string (nullable = true)
#  |    |    |    |-- QID19_2: string (nullable = true)
#  |    |    |    |-- QID19_3: string (nullable = true)
#  |    |    |    |-- QID2: string (nullable = true)
#  |    |    |    |-- QID21_1: string (nullable = true)
#  |    |    |    |-- QID21_2: string (nullable = true)
#  |    |    |    |-- QID21_3: string (nullable = true)
#  |    |    |    |-- QID21_4: string (nullable = true)
#  |    |    |    |-- QID21_5: string (nullable = true)
#  |    |    |    |-- QID21_6: string (nullable = true)
#  |    |    |    |-- QID21_7: string (nullable = true)
#  |    |    |    |-- QID23: string (nullable = true)
#  |    |    |    |-- QID24_1: string (nullable = true)
#  |    |    |    |-- QID24_2: string (nullable = true)
#  |    |    |    |-- QID24_3: string (nullable = true)
#  |    |    |    |-- QID24_4: string (nullable = true)
#  |    |    |    |-- QID24_5: string (nullable = true)
#  |    |    |    |-- QID27: string (nullable = true)
#  |    |    |    |-- QID28_1: string (nullable = true)
#  |    |    |    |-- QID28_2: string (nullable = true)
#  |    |    |    |-- QID28_3: string (nullable = true)
#  |    |    |    |-- QID28_4: string (nullable = true)
#  |    |    |    |-- QID28_5: string (nullable = true)
#  |    |    |    |-- QID28_6: string (nullable = true)
#  |    |    |    |-- QID28_7: string (nullable = true)
#  |    |    |    |-- QID28_8: string (nullable = true)
#  |    |    |    |-- QID3: string (nullable = true)
#  |    |    |    |-- QID33: string (nullable = true)
#  |    |    |    |-- QID34: string (nullable = true)
#  |    |    |    |-- QID35_1: string (nullable = true)
#  |    |    |    |-- QID35_2: string (nullable = true)
#  |    |    |    |-- QID35_3: string (nullable = true)
#  |    |    |    |-- QID35_4: string (nullable = true)
#  |    |    |    |-- QID35_5: string (nullable = true)
#  |    |    |    |-- QID35_6: string (nullable = true)
#  |    |    |    |-- QID35_7: string (nullable = true)
#  |    |    |    |-- QID35_9: string (nullable = true)
#  |    |    |    |-- QID37: string (nullable = true)
#  |    |    |    |-- QID38_1: string (nullable = true)
#  |    |    |    |-- QID38_2: string (nullable = true)
#  |    |    |    |-- QID38_3: string (nullable = true)
#  |    |    |    |-- QID38_5: string (nullable = true)
#  |    |    |    |-- QID4: string (nullable = true)
#  |    |    |    |-- QID40: string (nullable = true)
#  |    |    |    |-- QID41_1: string (nullable = true)
#  |    |    |    |-- QID41_2: string (nullable = true)
#  |    |    |    |-- QID41_3: string (nullable = true)
#  |    |    |    |-- QID41_4: string (nullable = true)
#  |    |    |    |-- QID41_5: string (nullable = true)
#  |    |    |    |-- QID41_6: string (nullable = true)
#  |    |    |    |-- QID41_7: string (nullable = true)
#  |    |    |    |-- QID41_8: string (nullable = true)
#  |    |    |    |-- QID42: string (nullable = true)
#  |    |    |    |-- QID47: string (nullable = true)
#  |    |    |    |-- QID48: string (nullable = true)
#  |    |    |    |-- QID5: string (nullable = true)
#  |    |    |    |-- QID7_1: string (nullable = true)
#  |    |    |    |-- QID7_2: string (nullable = true)
#  |    |    |    |-- QID7_3: string (nullable = true)
#  |    |    |    |-- QID7_4: string (nullable = true)
#  |    |    |    |-- QID7_5: string (nullable = true)
#  |    |    |    |-- QID7_6: string (nullable = true)
#  |    |    |    |-- QID7_7: string (nullable = true)
#  |    |    |    |-- QID7_8: string (nullable = true)
#  |    |    |    |-- QID9: string (nullable = true)
#  |    |    |    |-- QID94: string (nullable = true)
#  |    |    |    |-- finished: string (nullable = true)
#  |    |    |    |-- status: string (nullable = true)

# %%
# move responseId, values and labels  to top level schema

# Explode the 'responses' array to break it into individual rows
df_flattened = df.withColumn("response", F.explode("responses"))

# Select the 'responseId' at the top level, but retain 'values' and 'labels' as nested structures
df_flattened = df_flattened.select(
    "response.responseId",  # Move 'responseId' to the top level
    "response.values",       # Keep 'values' as a nested struct
    "response.labels"        # Keep 'labels' as a nested struct
)

# Show the updated schema
df_flattened.printSchema()

# Show the data to verify the transformation
df_flattened.show()
# Out:
# root
#  |-- responseId: string (nullable = true)
#  |-- values: struct (nullable = true)
#  |    |-- AccountName: string (nullable = true)
#  |    |-- AccountName_5e02b1554bfe4b0dac61f801SenPol: long (nullable = true)
#  |    |-- AccountName_5e02b1554bfe4b0dac61f801SenScore: long (nullable = true)
#  |    |-- BPCode: string (nullable = true)
#  |    |-- COVIDComments: string (nullable = true)
#  |    |-- CRMLink: string (nullable = true)
#  |    |-- CRMOwner: string (nullable = true)
#  |    |-- CRMOwnerEmail: string (nullable = true)
#  |    |-- ContactArea: string (nullable = true)
#  |    |-- ContactAreaCode: string (nullable = true)
#  |    |-- ContactCountry: string (nullable = true)
#  |    |-- ContactCountryCode: string (nullable = true)
#  |    |-- ContactEmail: string (nullable = true)
#  |    |-- ContactName: string (nullable = true)
#  |    |-- CustomerType: string (nullable = true)
#  |    |-- Digital: string (nullable = true)
#  |    |-- Distinction: string (nullable = true)
#  |    |-- GlobalCode: string (nullable = true)
#  |    |-- GlobalName: string (nullable = true)
#  |    |-- Guide: string (nullable = true)
#  |    |-- LST: string (nullable = true)
#  |    |-- OwnerArea: string (nullable = true)
#  |    |-- OwnerAreaCode: string (nullable = true)
#  |    |-- OwnerCountry: string (nullable = true)
#  |    |-- OwnerCountryCode: string (nullable = true)
#  |    |-- PrimaryBusiness: string (nullable = true)
#  |    |-- PrimaryBusinessGroup: string (nullable = true)
#  |    |-- PrimaryMajorMarket: string (nullable = true)
#  |    |-- QID101: long (nullable = true)
#  |    |-- QID103_1: long (nullable = true)
#  |    |-- QID103_2: long (nullable = true)
#  |    |-- QID103_3: long (nullable = true)
#  |    |-- QID103_4: long (nullable = true)
#  |    |-- QID103_5: long (nullable = true)
#  |    |-- QID103_6: long (nullable = true)
#  |    |-- QID103_7: long (nullable = true)
#  |    |-- QID103_8: long (nullable = true)
#  |    |-- QID103_9: long (nullable = true)
#  |    |-- QID105_TEXT: string (nullable = true)
#  |    |-- QID106: long (nullable = true)
#  |    |-- QID107: long (nullable = true)
#  |    |-- QID108: long (nullable = true)
#  |    |-- QID10_1: long (nullable = true)
#  |    |-- QID10_2: long (nullable = true)
#  |    |-- QID10_3: long (nullable = true)
#  |    |-- QID10_4: long (nullable = true)
#  |    |-- QID10_5: long (nullable = true)
#  |    |-- QID10_6: long (nullable = true)
#  |    |-- QID119: long (nullable = true)
#  |    |-- QID11_TEXT: string (nullable = true)
#  |    |-- QID11_TEXT_TRANSLATEDen93ihhyq: string (nullable = true)
#  |    |-- QID12: long (nullable = true)
#  |    |-- QID120_1: long (nullable = true)
#  |    |-- QID120_2: long (nullable = true)
#  |    |-- QID120_3: long (nullable = true)
#  |    |-- QID120_4: long (nullable = true)
#  |    |-- QID120_5: long (nullable = true)
#  |    |-- QID120_6: long (nullable = true)
#  |    |-- QID120_7: long (nullable = true)
#  |    |-- QID120_8: long (nullable = true)
#  |    |-- QID121_TEXT: string (nullable = true)
#  |    |-- QID128: long (nullable = true)
#  |    |-- QID130_1: long (nullable = true)
#  |    |-- QID130_10: long (nullable = true)
#  |    |-- QID130_2: long (nullable = true)
#  |    |-- QID130_3: long (nullable = true)
#  |    |-- QID130_4: long (nullable = true)
#  |    |-- QID130_6: long (nullable = true)
#  |    |-- QID130_7: long (nullable = true)
#  |    |-- QID130_8: long (nullable = true)
#  |    |-- QID130_9: long (nullable = true)
#  |    |-- QID131_TEXT: string (nullable = true)
#  |    |-- QID131_TEXT_TRANSLATEDenn363j8m: string (nullable = true)
#  |    |-- QID133: long (nullable = true)
#  |    |-- QID135: long (nullable = true)
#  |    |-- QID135_3_TEXT: string (nullable = true)
#  |    |-- QID135_3_TEXT_TRANSLATEDen8wvxb4h: string (nullable = true)
#  |    |-- QID137_1: long (nullable = true)
#  |    |-- QID137_2: long (nullable = true)
#  |    |-- QID137_3: long (nullable = true)
#  |    |-- QID137_4: long (nullable = true)
#  |    |-- QID137_5: long (nullable = true)
#  |    |-- QID137_6: long (nullable = true)
#  |    |-- QID137_7: long (nullable = true)
#  |    |-- QID137_8: long (nullable = true)
#  |    |-- QID138: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID139_TEXT: string (nullable = true)
#  |    |-- QID139_TEXT_TRANSLATEDen8qtubni: string (nullable = true)
#  |    |-- QID13_1: long (nullable = true)
#  |    |-- QID13_2: long (nullable = true)
#  |    |-- QID13_3: long (nullable = true)
#  |    |-- QID13_4: long (nullable = true)
#  |    |-- QID13_5: long (nullable = true)
#  |    |-- QID13_6: long (nullable = true)
#  |    |-- QID13_7: long (nullable = true)
#  |    |-- QID13_8: long (nullable = true)
#  |    |-- QID142_BROWSER: string (nullable = true)
#  |    |-- QID142_OS: string (nullable = true)
#  |    |-- QID142_RESOLUTION: string (nullable = true)
#  |    |-- QID142_VERSION: string (nullable = true)
#  |    |-- QID143_9_TEXT_TRANSLATEDenqvga6ad: string (nullable = true)
#  |    |-- QID144: long (nullable = true)
#  |    |-- QID145_1: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_2: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_3: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_5: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_9: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_9_TEXT: string (nullable = true)
#  |    |-- QID145_9_TEXT_TRANSLATEDen5op1zyu: string (nullable = true)
#  |    |-- QID146: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID146_9_TEXT: string (nullable = true)
#  |    |-- QID146_9_TEXT_TRANSLATEDenl7jzo6e: string (nullable = true)
#  |    |-- QID149: long (nullable = true)
#  |    |-- QID14_TEXT: string (nullable = true)
#  |    |-- QID14_TEXT_5e02b1554bfe4b0dac61f801SenPol: long (nullable = true)
#  |    |-- QID14_TEXT_5e02b1554bfe4b0dac61f801SenScore: long (nullable = true)
#  |    |-- QID14_TEXT_TRANSLATEDenwohlzuj: string (nullable = true)
#  |    |-- QID15: long (nullable = true)
#  |    |-- QID16_1: long (nullable = true)
#  |    |-- QID16_2: long (nullable = true)
#  |    |-- QID16_3: long (nullable = true)
#  |    |-- QID16_4: long (nullable = true)
#  |    |-- QID16_5: long (nullable = true)
#  |    |-- QID17_TEXT: string (nullable = true)
#  |    |-- QID17_TEXT_TRANSLATEDenre9rccw: string (nullable = true)
#  |    |-- QID18: long (nullable = true)
#  |    |-- QID19_1: long (nullable = true)
#  |    |-- QID19_2: long (nullable = true)
#  |    |-- QID19_3: long (nullable = true)
#  |    |-- QID2: long (nullable = true)
#  |    |-- QID20_TEXT: string (nullable = true)
#  |    |-- QID20_TEXT_TRANSLATEDen1ao9nhu: string (nullable = true)
#  |    |-- QID21_1: long (nullable = true)
#  |    |-- QID21_2: long (nullable = true)
#  |    |-- QID21_3: long (nullable = true)
#  |    |-- QID21_4: long (nullable = true)
#  |    |-- QID21_5: long (nullable = true)
#  |    |-- QID21_6: long (nullable = true)
#  |    |-- QID21_7: long (nullable = true)
#  |    |-- QID22_TEXT: string (nullable = true)
#  |    |-- QID22_TEXT_TRANSLATEDens1qb5u1: string (nullable = true)
#  |    |-- QID23: long (nullable = true)
#  |    |-- QID24_1: long (nullable = true)
#  |    |-- QID24_2: long (nullable = true)
#  |    |-- QID24_3: long (nullable = true)
#  |    |-- QID24_4: long (nullable = true)
#  |    |-- QID24_5: long (nullable = true)
#  |    |-- QID25_TEXT: string (nullable = true)
#  |    |-- QID25_TEXT_TRANSLATEDenly9xu00: string (nullable = true)
#  |    |-- QID27: long (nullable = true)
#  |    |-- QID28_1: long (nullable = true)
#  |    |-- QID28_2: long (nullable = true)
#  |    |-- QID28_3: long (nullable = true)
#  |    |-- QID28_4: long (nullable = true)
#  |    |-- QID28_5: long (nullable = true)
#  |    |-- QID28_6: long (nullable = true)
#  |    |-- QID28_7: long (nullable = true)
#  |    |-- QID28_8: long (nullable = true)
#  |    |-- QID29_TEXT: string (nullable = true)
#  |    |-- QID29_TEXT_TRANSLATEDenwvw39mf: string (nullable = true)
#  |    |-- QID2_5_TEXT: string (nullable = true)
#  |    |-- QID2_5_TEXT_TRANSLATEDenekufezj: string (nullable = true)
#  |    |-- QID3: long (nullable = true)
#  |    |-- QID33: long (nullable = true)
#  |    |-- QID34: long (nullable = true)
#  |    |-- QID35_1: long (nullable = true)
#  |    |-- QID35_2: long (nullable = true)
#  |    |-- QID35_3: long (nullable = true)
#  |    |-- QID35_4: long (nullable = true)
#  |    |-- QID35_5: long (nullable = true)
#  |    |-- QID35_6: long (nullable = true)
#  |    |-- QID35_7: long (nullable = true)
#  |    |-- QID35_9: long (nullable = true)
#  |    |-- QID36_TEXT: string (nullable = true)
#  |    |-- QID36_TEXT_TRANSLATEDen6kfua67: string (nullable = true)
#  |    |-- QID37: long (nullable = true)
#  |    |-- QID38_1: long (nullable = true)
#  |    |-- QID38_2: long (nullable = true)
#  |    |-- QID38_3: long (nullable = true)
#  |    |-- QID38_5: long (nullable = true)
#  |    |-- QID39_TEXT: string (nullable = true)
#  |    |-- QID39_TEXT_TRANSLATEDeni4c8ssx: string (nullable = true)
#  |    |-- QID4: long (nullable = true)
#  |    |-- QID40: long (nullable = true)
#  |    |-- QID41_1: long (nullable = true)
#  |    |-- QID41_2: long (nullable = true)
#  |    |-- QID41_3: long (nullable = true)
#  |    |-- QID41_4: long (nullable = true)
#  |    |-- QID41_5: long (nullable = true)
#  |    |-- QID41_6: long (nullable = true)
#  |    |-- QID41_7: long (nullable = true)
#  |    |-- QID41_8: long (nullable = true)
#  |    |-- QID42: long (nullable = true)
#  |    |-- QID43_TEXT: string (nullable = true)
#  |    |-- QID43_TEXT_TRANSLATEDenu8vx5gc: string (nullable = true)
#  |    |-- QID44_TEXT: string (nullable = true)
#  |    |-- QID44_TEXT_TRANSLATEDen6m3495e: string (nullable = true)
#  |    |-- QID47: long (nullable = true)
#  |    |-- QID48: long (nullable = true)
#  |    |-- QID49_TEXT: string (nullable = true)
#  |    |-- QID49_TEXT_TRANSLATEDeni0zgv8j: string (nullable = true)
#  |    |-- QID5: long (nullable = true)
#  |    |-- QID50_TEXT: string (nullable = true)
#  |    |-- QID50_TEXT_TRANSLATEDen10pb0wp: string (nullable = true)
#  |    |-- QID6_TEXT: string (nullable = true)
#  |    |-- QID6_TEXT_TRANSLATEDena6a9kkj: string (nullable = true)
#  |    |-- QID7_1: long (nullable = true)
#  |    |-- QID7_2: long (nullable = true)
#  |    |-- QID7_3: long (nullable = true)
#  |    |-- QID7_4: long (nullable = true)
#  |    |-- QID7_5: long (nullable = true)
#  |    |-- QID7_6: long (nullable = true)
#  |    |-- QID7_7: long (nullable = true)
#  |    |-- QID7_8: long (nullable = true)
#  |    |-- QID8_TEXT: string (nullable = true)
#  |    |-- QID8_TEXT_TRANSLATEDenue1spzz: string (nullable = true)
#  |    |-- QID9: long (nullable = true)
#  |    |-- QID94: long (nullable = true)
#  |    |-- Q_Language: string (nullable = true)
#  |    |-- Quarter: string (nullable = true)
#  |    |-- QuarterRollup: string (nullable = true)
#  |    |-- QuarterYear: string (nullable = true)
#  |    |-- Randomized_ID: string (nullable = true)
#  |    |-- Region: string (nullable = true)
#  |    |-- SalName: string (nullable = true)
#  |    |-- Score: string (nullable = true)
#  |    |-- SellerEmail: string (nullable = true)
#  |    |-- SellerEmailSSO: string (nullable = true)
#  |    |-- SellerName: string (nullable = true)
#  |    |-- StrategicName: string (nullable = true)
#  |    |-- Submit: string (nullable = true)
#  |    |-- SustainabilityLanguageFilter: string (nullable = true)
#  |    |-- Year: string (nullable = true)
#  |    |-- _recordId: string (nullable = true)
#  |    |-- distributionChannel: string (nullable = true)
#  |    |-- duration: long (nullable = true)
#  |    |-- endDate: string (nullable = true)
#  |    |-- finished: long (nullable = true)
#  |    |-- ipAddress: string (nullable = true)
#  |    |-- locationLatitude: string (nullable = true)
#  |    |-- locationLongitude: string (nullable = true)
#  |    |-- progress: long (nullable = true)
#  |    |-- recipientEmail: string (nullable = true)
#  |    |-- recipientFirstName: string (nullable = true)
#  |    |-- recipientLastName: string (nullable = true)
#  |    |-- recordedDate: string (nullable = true)
#  |    |-- startDate: string (nullable = true)
#  |    |-- status: long (nullable = true)
#  |    |-- userLanguage: string (nullable = true)
#  |-- labels: struct (nullable = true)
#  |    |-- QID101: string (nullable = true)
#  |    |-- QID103_1: string (nullable = true)
#  |    |-- QID103_2: string (nullable = true)
#  |    |-- QID103_3: string (nullable = true)
#  |    |-- QID103_4: string (nullable = true)
#  |    |-- QID103_5: string (nullable = true)
#  |    |-- QID103_6: string (nullable = true)
#  |    |-- QID103_7: string (nullable = true)
#  |    |-- QID103_8: string (nullable = true)
#  |    |-- QID103_9: string (nullable = true)
#  |    |-- QID106: string (nullable = true)
#  |    |-- QID107: string (nullable = true)
#  |    |-- QID108: string (nullable = true)
#  |    |-- QID10_1: string (nullable = true)
#  |    |-- QID10_2: string (nullable = true)
#  |    |-- QID10_3: string (nullable = true)
#  |    |-- QID10_4: string (nullable = true)
#  |    |-- QID10_5: string (nullable = true)
#  |    |-- QID10_6: string (nullable = true)
#  |    |-- QID119: string (nullable = true)
#  |    |-- QID12: string (nullable = true)
#  |    |-- QID120_1: string (nullable = true)
#  |    |-- QID120_2: string (nullable = true)
#  |    |-- QID120_3: string (nullable = true)
#  |    |-- QID120_4: string (nullable = true)
#  |    |-- QID120_5: string (nullable = true)
#  |    |-- QID120_6: string (nullable = true)
#  |    |-- QID120_7: string (nullable = true)
#  |    |-- QID120_8: string (nullable = true)
#  |    |-- QID128: string (nullable = true)
#  |    |-- QID130_1: string (nullable = true)
#  |    |-- QID130_10: string (nullable = true)
#  |    |-- QID130_2: string (nullable = true)
#  |    |-- QID130_3: string (nullable = true)
#  |    |-- QID130_4: string (nullable = true)
#  |    |-- QID130_6: string (nullable = true)
#  |    |-- QID130_7: string (nullable = true)
#  |    |-- QID130_8: string (nullable = true)
#  |    |-- QID130_9: string (nullable = true)
#  |    |-- QID133: string (nullable = true)
#  |    |-- QID135: string (nullable = true)
#  |    |-- QID137_1: string (nullable = true)
#  |    |-- QID137_2: string (nullable = true)
#  |    |-- QID137_3: string (nullable = true)
#  |    |-- QID137_4: string (nullable = true)
#  |    |-- QID137_5: string (nullable = true)
#  |    |-- QID137_6: string (nullable = true)
#  |    |-- QID137_7: string (nullable = true)
#  |    |-- QID137_8: string (nullable = true)
#  |    |-- QID138: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID13_1: string (nullable = true)
#  |    |-- QID13_2: string (nullable = true)
#  |    |-- QID13_3: string (nullable = true)
#  |    |-- QID13_4: string (nullable = true)
#  |    |-- QID13_5: string (nullable = true)
#  |    |-- QID13_6: string (nullable = true)
#  |    |-- QID13_7: string (nullable = true)
#  |    |-- QID13_8: string (nullable = true)
#  |    |-- QID144: string (nullable = true)
#  |    |-- QID145_1: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_2: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_3: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_5: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_9: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID146: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID149: string (nullable = true)
#  |    |-- QID15: string (nullable = true)
#  |    |-- QID16_1: string (nullable = true)
#  |    |-- QID16_2: string (nullable = true)
#  |    |-- QID16_3: string (nullable = true)
#  |    |-- QID16_4: string (nullable = true)
#  |    |-- QID16_5: string (nullable = true)
#  |    |-- QID18: string (nullable = true)
#  |    |-- QID19_1: string (nullable = true)
#  |    |-- QID19_2: string (nullable = true)
#  |    |-- QID19_3: string (nullable = true)
#  |    |-- QID2: string (nullable = true)
#  |    |-- QID21_1: string (nullable = true)
#  |    |-- QID21_2: string (nullable = true)
#  |    |-- QID21_3: string (nullable = true)
#  |    |-- QID21_4: string (nullable = true)
#  |    |-- QID21_5: string (nullable = true)
#  |    |-- QID21_6: string (nullable = true)
#  |    |-- QID21_7: string (nullable = true)
#  |    |-- QID23: string (nullable = true)
#  |    |-- QID24_1: string (nullable = true)
#  |    |-- QID24_2: string (nullable = true)
#  |    |-- QID24_3: string (nullable = true)
#  |    |-- QID24_4: string (nullable = true)
#  |    |-- QID24_5: string (nullable = true)
#  |    |-- QID27: string (nullable = true)
#  |    |-- QID28_1: string (nullable = true)
#  |    |-- QID28_2: string (nullable = true)
#  |    |-- QID28_3: string (nullable = true)
#  |    |-- QID28_4: string (nullable = true)
#  |    |-- QID28_5: string (nullable = true)
#  |    |-- QID28_6: string (nullable = true)
#  |    |-- QID28_7: string (nullable = true)
#  |    |-- QID28_8: string (nullable = true)
#  |    |-- QID3: string (nullable = true)
#  |    |-- QID33: string (nullable = true)
#  |    |-- QID34: string (nullable = true)
#  |    |-- QID35_1: string (nullable = true)
#  |    |-- QID35_2: string (nullable = true)
#  |    |-- QID35_3: string (nullable = true)
#  |    |-- QID35_4: string (nullable = true)
#  |    |-- QID35_5: string (nullable = true)
#  |    |-- QID35_6: string (nullable = true)
#  |    |-- QID35_7: string (nullable = true)
#  |    |-- QID35_9: string (nullable = true)
#  |    |-- QID37: string (nullable = true)
#  |    |-- QID38_1: string (nullable = true)
#  |    |-- QID38_2: string (nullable = true)
#  |    |-- QID38_3: string (nullable = true)
#  |    |-- QID38_5: string (nullable = true)
#  |    |-- QID4: string (nullable = true)
#  |    |-- QID40: string (nullable = true)
#  |    |-- QID41_1: string (nullable = true)
#  |    |-- QID41_2: string (nullable = true)
#  |    |-- QID41_3: string (nullable = true)
#  |    |-- QID41_4: string (nullable = true)
#  |    |-- QID41_5: string (nullable = true)
#  |    |-- QID41_6: string (nullable = true)
#  |    |-- QID41_7: string (nullable = true)
#  |    |-- QID41_8: string (nullable = true)
#  |    |-- QID42: string (nullable = true)
#  |    |-- QID47: string (nullable = true)
#  |    |-- QID48: string (nullable = true)
#  |    |-- QID5: string (nullable = true)
#  |    |-- QID7_1: string (nullable = true)
#  |    |-- QID7_2: string (nullable = true)
#  |    |-- QID7_3: string (nullable = true)
#  |    |-- QID7_4: string (nullable = true)
#  |    |-- QID7_5: string (nullable = true)
#  |    |-- QID7_6: string (nullable = true)
#  |    |-- QID7_7: string (nullable = true)
#  |    |-- QID7_8: string (nullable = true)
#  |    |-- QID9: string (nullable = true)
#  |    |-- QID94: string (nullable = true)
#  |    |-- finished: string (nullable = true)
#  |    |-- status: string (nullable = true)
#
# +-----------------+--------------------+--------------------+
# |       responseId|              values|              labels|
# +-----------------+--------------------+--------------------+
# |R_0PnhCMZ1PdNVYG2|{SOLEXX SRL, 0, 1...|{NULL, NULL, NULL...|
# |R_6F1hg85nwVTfLZI|{ALGAR S A, NULL,...|{NULL, NULL, NULL...|
# |R_79cYtfdd5SUpPiC|{WATTYL KILBURN, ...|{NULL, NULL, NULL...|
# |R_863AaAfnriqVJ1Y|{SOCIEDAD COMERCI...|{NULL, NULL, NULL...|
# |R_1AGPqAIceTKQ1O6|{INDUTIL INDUST -...|{NULL, NULL, NULL...|
# |R_3QarU6gEALuxNhI|{EUCATEX - SAO PA...|{NULL, NULL, NULL...|
# |R_6tjTmTQXwdrvnRY|{MPC PROKIM INDUS...|{NULL, NULL, NULL...|
# |R_a93vqnlzw9NxAkS|{SHERWIN WILLIAMS...|{NULL, NULL, NULL...|
# |R_dhyWO8MudIX5pqe|{CERESITA - SANTI...|{NULL, NULL, NULL...|
# |R_ehvBUo5RAwFSWnI|{VIMASTER IND E C...|{NULL, NULL, NULL...|
# |R_esQhMB8yDWXVm18|{SUZANO CELULOSE ...|{NULL, NULL, NULL...|
# |R_38hFtDXWuW9svUa|{SINTEPLAST - CAR...|{NULL, NULL, NULL...|
# |R_3K6aEcIqtIUx6rI|{TRICOLOR - VINA ...|{NULL, NULL, NULL...|
# |R_6rMJSbjjX2JVaIK|{DIRANSA - CAPITA...|{NULL, NULL, NULL...|
# |R_74G3NjcufDel5si|{ALGAR S A, NULL,...|{NULL, NULL, NULL...|
# |R_9oSLmqbZqr7G1ds|{SINTEPLAST - CAR...|{NULL, NULL, NULL...|
# |R_cBglPVW1G0IsRue|{SOCIEDAD COMERCI...|{NULL, NULL, NULL...|
# |R_e2KQuH4FroNnPQa|{EUCATEX - SAO PA...|{NULL, NULL, NULL...|
# |R_2fe3q4vRHd1FBxc|{COMPTOIR DE COMM...|{NULL, NULL, NULL...|
# |R_3a7odBs5qbUiVDw|{ENNIS TRAFFIC SA...|{NULL, NULL, NULL...|
# +-----------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# convert values keys to columns
df_values = df_flattened.select(
    "responseId",
    *[F.col(f"values.{c}").alias(c) for c in df_flattened.schema["values"].dataType.fieldNames()]
)
df_values.printSchema()
# Out:
# root
#  |-- responseId: string (nullable = true)
#  |-- AccountName: string (nullable = true)
#  |-- AccountName_5e02b1554bfe4b0dac61f801SenPol: long (nullable = true)
#  |-- AccountName_5e02b1554bfe4b0dac61f801SenScore: long (nullable = true)
#  |-- BPCode: string (nullable = true)
#  |-- COVIDComments: string (nullable = true)
#  |-- CRMLink: string (nullable = true)
#  |-- CRMOwner: string (nullable = true)
#  |-- CRMOwnerEmail: string (nullable = true)
#  |-- ContactArea: string (nullable = true)
#  |-- ContactAreaCode: string (nullable = true)
#  |-- ContactCountry: string (nullable = true)
#  |-- ContactCountryCode: string (nullable = true)
#  |-- ContactEmail: string (nullable = true)
#  |-- ContactName: string (nullable = true)
#  |-- CustomerType: string (nullable = true)
#  |-- Digital: string (nullable = true)
#  |-- Distinction: string (nullable = true)
#  |-- GlobalCode: string (nullable = true)
#  |-- GlobalName: string (nullable = true)
#  |-- Guide: string (nullable = true)
#  |-- LST: string (nullable = true)
#  |-- OwnerArea: string (nullable = true)
#  |-- OwnerAreaCode: string (nullable = true)
#  |-- OwnerCountry: string (nullable = true)
#  |-- OwnerCountryCode: string (nullable = true)
#  |-- PrimaryBusiness: string (nullable = true)
#  |-- PrimaryBusinessGroup: string (nullable = true)
#  |-- PrimaryMajorMarket: string (nullable = true)
#  |-- QID101: long (nullable = true)
#  |-- QID103_1: long (nullable = true)
#  |-- QID103_2: long (nullable = true)
#  |-- QID103_3: long (nullable = true)
#  |-- QID103_4: long (nullable = true)
#  |-- QID103_5: long (nullable = true)
#  |-- QID103_6: long (nullable = true)
#  |-- QID103_7: long (nullable = true)
#  |-- QID103_8: long (nullable = true)
#  |-- QID103_9: long (nullable = true)
#  |-- QID105_TEXT: string (nullable = true)
#  |-- QID106: long (nullable = true)
#  |-- QID107: long (nullable = true)
#  |-- QID108: long (nullable = true)
#  |-- QID10_1: long (nullable = true)
#  |-- QID10_2: long (nullable = true)
#  |-- QID10_3: long (nullable = true)
#  |-- QID10_4: long (nullable = true)
#  |-- QID10_5: long (nullable = true)
#  |-- QID10_6: long (nullable = true)
#  |-- QID119: long (nullable = true)
#  |-- QID11_TEXT: string (nullable = true)
#  |-- QID11_TEXT_TRANSLATEDen93ihhyq: string (nullable = true)
#  |-- QID12: long (nullable = true)
#  |-- QID120_1: long (nullable = true)
#  |-- QID120_2: long (nullable = true)
#  |-- QID120_3: long (nullable = true)
#  |-- QID120_4: long (nullable = true)
#  |-- QID120_5: long (nullable = true)
#  |-- QID120_6: long (nullable = true)
#  |-- QID120_7: long (nullable = true)
#  |-- QID120_8: long (nullable = true)
#  |-- QID121_TEXT: string (nullable = true)
#  |-- QID128: long (nullable = true)
#  |-- QID130_1: long (nullable = true)
#  |-- QID130_10: long (nullable = true)
#  |-- QID130_2: long (nullable = true)
#  |-- QID130_3: long (nullable = true)
#  |-- QID130_4: long (nullable = true)
#  |-- QID130_6: long (nullable = true)
#  |-- QID130_7: long (nullable = true)
#  |-- QID130_8: long (nullable = true)
#  |-- QID130_9: long (nullable = true)
#  |-- QID131_TEXT: string (nullable = true)
#  |-- QID131_TEXT_TRANSLATEDenn363j8m: string (nullable = true)
#  |-- QID133: long (nullable = true)
#  |-- QID135: long (nullable = true)
#  |-- QID135_3_TEXT: string (nullable = true)
#  |-- QID135_3_TEXT_TRANSLATEDen8wvxb4h: string (nullable = true)
#  |-- QID137_1: long (nullable = true)
#  |-- QID137_2: long (nullable = true)
#  |-- QID137_3: long (nullable = true)
#  |-- QID137_4: long (nullable = true)
#  |-- QID137_5: long (nullable = true)
#  |-- QID137_6: long (nullable = true)
#  |-- QID137_7: long (nullable = true)
#  |-- QID137_8: long (nullable = true)
#  |-- QID138: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID139_TEXT: string (nullable = true)
#  |-- QID139_TEXT_TRANSLATEDen8qtubni: string (nullable = true)
#  |-- QID13_1: long (nullable = true)
#  |-- QID13_2: long (nullable = true)
#  |-- QID13_3: long (nullable = true)
#  |-- QID13_4: long (nullable = true)
#  |-- QID13_5: long (nullable = true)
#  |-- QID13_6: long (nullable = true)
#  |-- QID13_7: long (nullable = true)
#  |-- QID13_8: long (nullable = true)
#  |-- QID142_BROWSER: string (nullable = true)
#  |-- QID142_OS: string (nullable = true)
#  |-- QID142_RESOLUTION: string (nullable = true)
#  |-- QID142_VERSION: string (nullable = true)
#  |-- QID143_9_TEXT_TRANSLATEDenqvga6ad: string (nullable = true)
#  |-- QID144: long (nullable = true)
#  |-- QID145_1: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_2: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_3: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_5: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_9: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_9_TEXT: string (nullable = true)
#  |-- QID145_9_TEXT_TRANSLATEDen5op1zyu: string (nullable = true)
#  |-- QID146: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID146_9_TEXT: string (nullable = true)
#  |-- QID146_9_TEXT_TRANSLATEDenl7jzo6e: string (nullable = true)
#  |-- QID149: long (nullable = true)
#  |-- QID14_TEXT: string (nullable = true)
#  |-- QID14_TEXT_5e02b1554bfe4b0dac61f801SenPol: long (nullable = true)
#  |-- QID14_TEXT_5e02b1554bfe4b0dac61f801SenScore: long (nullable = true)
#  |-- QID14_TEXT_TRANSLATEDenwohlzuj: string (nullable = true)
#  |-- QID15: long (nullable = true)
#  |-- QID16_1: long (nullable = true)
#  |-- QID16_2: long (nullable = true)
#  |-- QID16_3: long (nullable = true)
#  |-- QID16_4: long (nullable = true)
#  |-- QID16_5: long (nullable = true)
#  |-- QID17_TEXT: string (nullable = true)
#  |-- QID17_TEXT_TRANSLATEDenre9rccw: string (nullable = true)
#  |-- QID18: long (nullable = true)
#  |-- QID19_1: long (nullable = true)
#  |-- QID19_2: long (nullable = true)
#  |-- QID19_3: long (nullable = true)
#  |-- QID2: long (nullable = true)
#  |-- QID20_TEXT: string (nullable = true)
#  |-- QID20_TEXT_TRANSLATEDen1ao9nhu: string (nullable = true)
#  |-- QID21_1: long (nullable = true)
#  |-- QID21_2: long (nullable = true)
#  |-- QID21_3: long (nullable = true)
#  |-- QID21_4: long (nullable = true)
#  |-- QID21_5: long (nullable = true)
#  |-- QID21_6: long (nullable = true)
#  |-- QID21_7: long (nullable = true)
#  |-- QID22_TEXT: string (nullable = true)
#  |-- QID22_TEXT_TRANSLATEDens1qb5u1: string (nullable = true)
#  |-- QID23: long (nullable = true)
#  |-- QID24_1: long (nullable = true)
#  |-- QID24_2: long (nullable = true)
#  |-- QID24_3: long (nullable = true)
#  |-- QID24_4: long (nullable = true)
#  |-- QID24_5: long (nullable = true)
#  |-- QID25_TEXT: string (nullable = true)
#  |-- QID25_TEXT_TRANSLATEDenly9xu00: string (nullable = true)
#  |-- QID27: long (nullable = true)
#  |-- QID28_1: long (nullable = true)
#  |-- QID28_2: long (nullable = true)
#  |-- QID28_3: long (nullable = true)
#  |-- QID28_4: long (nullable = true)
#  |-- QID28_5: long (nullable = true)
#  |-- QID28_6: long (nullable = true)
#  |-- QID28_7: long (nullable = true)
#  |-- QID28_8: long (nullable = true)
#  |-- QID29_TEXT: string (nullable = true)
#  |-- QID29_TEXT_TRANSLATEDenwvw39mf: string (nullable = true)
#  |-- QID2_5_TEXT: string (nullable = true)
#  |-- QID2_5_TEXT_TRANSLATEDenekufezj: string (nullable = true)
#  |-- QID3: long (nullable = true)
#  |-- QID33: long (nullable = true)
#  |-- QID34: long (nullable = true)
#  |-- QID35_1: long (nullable = true)
#  |-- QID35_2: long (nullable = true)
#  |-- QID35_3: long (nullable = true)
#  |-- QID35_4: long (nullable = true)
#  |-- QID35_5: long (nullable = true)
#  |-- QID35_6: long (nullable = true)
#  |-- QID35_7: long (nullable = true)
#  |-- QID35_9: long (nullable = true)
#  |-- QID36_TEXT: string (nullable = true)
#  |-- QID36_TEXT_TRANSLATEDen6kfua67: string (nullable = true)
#  |-- QID37: long (nullable = true)
#  |-- QID38_1: long (nullable = true)
#  |-- QID38_2: long (nullable = true)
#  |-- QID38_3: long (nullable = true)
#  |-- QID38_5: long (nullable = true)
#  |-- QID39_TEXT: string (nullable = true)
#  |-- QID39_TEXT_TRANSLATEDeni4c8ssx: string (nullable = true)
#  |-- QID4: long (nullable = true)
#  |-- QID40: long (nullable = true)
#  |-- QID41_1: long (nullable = true)
#  |-- QID41_2: long (nullable = true)
#  |-- QID41_3: long (nullable = true)
#  |-- QID41_4: long (nullable = true)
#  |-- QID41_5: long (nullable = true)
#  |-- QID41_6: long (nullable = true)
#  |-- QID41_7: long (nullable = true)
#  |-- QID41_8: long (nullable = true)
#  |-- QID42: long (nullable = true)
#  |-- QID43_TEXT: string (nullable = true)
#  |-- QID43_TEXT_TRANSLATEDenu8vx5gc: string (nullable = true)
#  |-- QID44_TEXT: string (nullable = true)
#  |-- QID44_TEXT_TRANSLATEDen6m3495e: string (nullable = true)
#  |-- QID47: long (nullable = true)
#  |-- QID48: long (nullable = true)
#  |-- QID49_TEXT: string (nullable = true)
#  |-- QID49_TEXT_TRANSLATEDeni0zgv8j: string (nullable = true)
#  |-- QID5: long (nullable = true)
#  |-- QID50_TEXT: string (nullable = true)
#  |-- QID50_TEXT_TRANSLATEDen10pb0wp: string (nullable = true)
#  |-- QID6_TEXT: string (nullable = true)
#  |-- QID6_TEXT_TRANSLATEDena6a9kkj: string (nullable = true)
#  |-- QID7_1: long (nullable = true)
#  |-- QID7_2: long (nullable = true)
#  |-- QID7_3: long (nullable = true)
#  |-- QID7_4: long (nullable = true)
#  |-- QID7_5: long (nullable = true)
#  |-- QID7_6: long (nullable = true)
#  |-- QID7_7: long (nullable = true)
#  |-- QID7_8: long (nullable = true)
#  |-- QID8_TEXT: string (nullable = true)
#  |-- QID8_TEXT_TRANSLATEDenue1spzz: string (nullable = true)
#  |-- QID9: long (nullable = true)
#  |-- QID94: long (nullable = true)
#  |-- Q_Language: string (nullable = true)
#  |-- Quarter: string (nullable = true)
#  |-- QuarterRollup: string (nullable = true)
#  |-- QuarterYear: string (nullable = true)
#  |-- Randomized_ID: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- SalName: string (nullable = true)
#  |-- Score: string (nullable = true)
#  |-- SellerEmail: string (nullable = true)
#  |-- SellerEmailSSO: string (nullable = true)
#  |-- SellerName: string (nullable = true)
#  |-- StrategicName: string (nullable = true)
#  |-- Submit: string (nullable = true)
#  |-- SustainabilityLanguageFilter: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- _recordId: string (nullable = true)
#  |-- distributionChannel: string (nullable = true)
#  |-- duration: long (nullable = true)
#  |-- endDate: string (nullable = true)
#  |-- finished: long (nullable = true)
#  |-- ipAddress: string (nullable = true)
#  |-- locationLatitude: string (nullable = true)
#  |-- locationLongitude: string (nullable = true)
#  |-- progress: long (nullable = true)
#  |-- recipientEmail: string (nullable = true)
#  |-- recipientFirstName: string (nullable = true)
#  |-- recipientLastName: string (nullable = true)
#  |-- recordedDate: string (nullable = true)
#  |-- startDate: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- userLanguage: string (nullable = true)

# %%
df_values_pandas = df_values.toPandas()
display(df_values_pandas)

# %% [markdown]
# # transforming the labels column

# %%
df_labels = df_flattened.select(F.col("responseId"), F.col("labels"))
df_labels.printSchema()
# Out:
# root
#  |-- responseId: string (nullable = true)
#  |-- labels: struct (nullable = true)
#  |    |-- QID101: string (nullable = true)
#  |    |-- QID103_1: string (nullable = true)
#  |    |-- QID103_2: string (nullable = true)
#  |    |-- QID103_3: string (nullable = true)
#  |    |-- QID103_4: string (nullable = true)
#  |    |-- QID103_5: string (nullable = true)
#  |    |-- QID103_6: string (nullable = true)
#  |    |-- QID103_7: string (nullable = true)
#  |    |-- QID103_8: string (nullable = true)
#  |    |-- QID103_9: string (nullable = true)
#  |    |-- QID106: string (nullable = true)
#  |    |-- QID107: string (nullable = true)
#  |    |-- QID108: string (nullable = true)
#  |    |-- QID10_1: string (nullable = true)
#  |    |-- QID10_2: string (nullable = true)
#  |    |-- QID10_3: string (nullable = true)
#  |    |-- QID10_4: string (nullable = true)
#  |    |-- QID10_5: string (nullable = true)
#  |    |-- QID10_6: string (nullable = true)
#  |    |-- QID119: string (nullable = true)
#  |    |-- QID12: string (nullable = true)
#  |    |-- QID120_1: string (nullable = true)
#  |    |-- QID120_2: string (nullable = true)
#  |    |-- QID120_3: string (nullable = true)
#  |    |-- QID120_4: string (nullable = true)
#  |    |-- QID120_5: string (nullable = true)
#  |    |-- QID120_6: string (nullable = true)
#  |    |-- QID120_7: string (nullable = true)
#  |    |-- QID120_8: string (nullable = true)
#  |    |-- QID128: string (nullable = true)
#  |    |-- QID130_1: string (nullable = true)
#  |    |-- QID130_10: string (nullable = true)
#  |    |-- QID130_2: string (nullable = true)
#  |    |-- QID130_3: string (nullable = true)
#  |    |-- QID130_4: string (nullable = true)
#  |    |-- QID130_6: string (nullable = true)
#  |    |-- QID130_7: string (nullable = true)
#  |    |-- QID130_8: string (nullable = true)
#  |    |-- QID130_9: string (nullable = true)
#  |    |-- QID133: string (nullable = true)
#  |    |-- QID135: string (nullable = true)
#  |    |-- QID137_1: string (nullable = true)
#  |    |-- QID137_2: string (nullable = true)
#  |    |-- QID137_3: string (nullable = true)
#  |    |-- QID137_4: string (nullable = true)
#  |    |-- QID137_5: string (nullable = true)
#  |    |-- QID137_6: string (nullable = true)
#  |    |-- QID137_7: string (nullable = true)
#  |    |-- QID137_8: string (nullable = true)
#  |    |-- QID138: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID13_1: string (nullable = true)
#  |    |-- QID13_2: string (nullable = true)
#  |    |-- QID13_3: string (nullable = true)
#  |    |-- QID13_4: string (nullable = true)
#  |    |-- QID13_5: string (nullable = true)
#  |    |-- QID13_6: string (nullable = true)
#  |    |-- QID13_7: string (nullable = true)
#  |    |-- QID13_8: string (nullable = true)
#  |    |-- QID144: string (nullable = true)
#  |    |-- QID145_1: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_2: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_3: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_5: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID145_9: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID146: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- QID149: string (nullable = true)
#  |    |-- QID15: string (nullable = true)
#  |    |-- QID16_1: string (nullable = true)
#  |    |-- QID16_2: string (nullable = true)
#  |    |-- QID16_3: string (nullable = true)
#  |    |-- QID16_4: string (nullable = true)
#  |    |-- QID16_5: string (nullable = true)
#  |    |-- QID18: string (nullable = true)
#  |    |-- QID19_1: string (nullable = true)
#  |    |-- QID19_2: string (nullable = true)
#  |    |-- QID19_3: string (nullable = true)
#  |    |-- QID2: string (nullable = true)
#  |    |-- QID21_1: string (nullable = true)
#  |    |-- QID21_2: string (nullable = true)
#  |    |-- QID21_3: string (nullable = true)
#  |    |-- QID21_4: string (nullable = true)
#  |    |-- QID21_5: string (nullable = true)
#  |    |-- QID21_6: string (nullable = true)
#  |    |-- QID21_7: string (nullable = true)
#  |    |-- QID23: string (nullable = true)
#  |    |-- QID24_1: string (nullable = true)
#  |    |-- QID24_2: string (nullable = true)
#  |    |-- QID24_3: string (nullable = true)
#  |    |-- QID24_4: string (nullable = true)
#  |    |-- QID24_5: string (nullable = true)
#  |    |-- QID27: string (nullable = true)
#  |    |-- QID28_1: string (nullable = true)
#  |    |-- QID28_2: string (nullable = true)
#  |    |-- QID28_3: string (nullable = true)
#  |    |-- QID28_4: string (nullable = true)
#  |    |-- QID28_5: string (nullable = true)
#  |    |-- QID28_6: string (nullable = true)
#  |    |-- QID28_7: string (nullable = true)
#  |    |-- QID28_8: string (nullable = true)
#  |    |-- QID3: string (nullable = true)
#  |    |-- QID33: string (nullable = true)
#  |    |-- QID34: string (nullable = true)
#  |    |-- QID35_1: string (nullable = true)
#  |    |-- QID35_2: string (nullable = true)
#  |    |-- QID35_3: string (nullable = true)
#  |    |-- QID35_4: string (nullable = true)
#  |    |-- QID35_5: string (nullable = true)
#  |    |-- QID35_6: string (nullable = true)
#  |    |-- QID35_7: string (nullable = true)
#  |    |-- QID35_9: string (nullable = true)
#  |    |-- QID37: string (nullable = true)
#  |    |-- QID38_1: string (nullable = true)
#  |    |-- QID38_2: string (nullable = true)
#  |    |-- QID38_3: string (nullable = true)
#  |    |-- QID38_5: string (nullable = true)
#  |    |-- QID4: string (nullable = true)
#  |    |-- QID40: string (nullable = true)
#  |    |-- QID41_1: string (nullable = true)
#  |    |-- QID41_2: string (nullable = true)
#  |    |-- QID41_3: string (nullable = true)
#  |    |-- QID41_4: string (nullable = true)
#  |    |-- QID41_5: string (nullable = true)
#  |    |-- QID41_6: string (nullable = true)
#  |    |-- QID41_7: string (nullable = true)
#  |    |-- QID41_8: string (nullable = true)
#  |    |-- QID42: string (nullable = true)
#  |    |-- QID47: string (nullable = true)
#  |    |-- QID48: string (nullable = true)
#  |    |-- QID5: string (nullable = true)
#  |    |-- QID7_1: string (nullable = true)
#  |    |-- QID7_2: string (nullable = true)
#  |    |-- QID7_3: string (nullable = true)
#  |    |-- QID7_4: string (nullable = true)
#  |    |-- QID7_5: string (nullable = true)
#  |    |-- QID7_6: string (nullable = true)
#  |    |-- QID7_7: string (nullable = true)
#  |    |-- QID7_8: string (nullable = true)
#  |    |-- QID9: string (nullable = true)
#  |    |-- QID94: string (nullable = true)
#  |    |-- finished: string (nullable = true)
#  |    |-- status: string (nullable = true)

# %%
# flatten labels column
df_labels = df_labels.select(
    "responseId",
    *[F.col(f"labels.{c}").alias(c) for c in df_labels.schema["labels"].dataType.fieldNames()]
)
df_labels.printSchema()
# Out:
# root
#  |-- responseId: string (nullable = true)
#  |-- QID101: string (nullable = true)
#  |-- QID103_1: string (nullable = true)
#  |-- QID103_2: string (nullable = true)
#  |-- QID103_3: string (nullable = true)
#  |-- QID103_4: string (nullable = true)
#  |-- QID103_5: string (nullable = true)
#  |-- QID103_6: string (nullable = true)
#  |-- QID103_7: string (nullable = true)
#  |-- QID103_8: string (nullable = true)
#  |-- QID103_9: string (nullable = true)
#  |-- QID106: string (nullable = true)
#  |-- QID107: string (nullable = true)
#  |-- QID108: string (nullable = true)
#  |-- QID10_1: string (nullable = true)
#  |-- QID10_2: string (nullable = true)
#  |-- QID10_3: string (nullable = true)
#  |-- QID10_4: string (nullable = true)
#  |-- QID10_5: string (nullable = true)
#  |-- QID10_6: string (nullable = true)
#  |-- QID119: string (nullable = true)
#  |-- QID12: string (nullable = true)
#  |-- QID120_1: string (nullable = true)
#  |-- QID120_2: string (nullable = true)
#  |-- QID120_3: string (nullable = true)
#  |-- QID120_4: string (nullable = true)
#  |-- QID120_5: string (nullable = true)
#  |-- QID120_6: string (nullable = true)
#  |-- QID120_7: string (nullable = true)
#  |-- QID120_8: string (nullable = true)
#  |-- QID128: string (nullable = true)
#  |-- QID130_1: string (nullable = true)
#  |-- QID130_10: string (nullable = true)
#  |-- QID130_2: string (nullable = true)
#  |-- QID130_3: string (nullable = true)
#  |-- QID130_4: string (nullable = true)
#  |-- QID130_6: string (nullable = true)
#  |-- QID130_7: string (nullable = true)
#  |-- QID130_8: string (nullable = true)
#  |-- QID130_9: string (nullable = true)
#  |-- QID133: string (nullable = true)
#  |-- QID135: string (nullable = true)
#  |-- QID137_1: string (nullable = true)
#  |-- QID137_2: string (nullable = true)
#  |-- QID137_3: string (nullable = true)
#  |-- QID137_4: string (nullable = true)
#  |-- QID137_5: string (nullable = true)
#  |-- QID137_6: string (nullable = true)
#  |-- QID137_7: string (nullable = true)
#  |-- QID137_8: string (nullable = true)
#  |-- QID138: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID13_1: string (nullable = true)
#  |-- QID13_2: string (nullable = true)
#  |-- QID13_3: string (nullable = true)
#  |-- QID13_4: string (nullable = true)
#  |-- QID13_5: string (nullable = true)
#  |-- QID13_6: string (nullable = true)
#  |-- QID13_7: string (nullable = true)
#  |-- QID13_8: string (nullable = true)
#  |-- QID144: string (nullable = true)
#  |-- QID145_1: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_2: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_3: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_5: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_9: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID146: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID149: string (nullable = true)
#  |-- QID15: string (nullable = true)
#  |-- QID16_1: string (nullable = true)
#  |-- QID16_2: string (nullable = true)
#  |-- QID16_3: string (nullable = true)
#  |-- QID16_4: string (nullable = true)
#  |-- QID16_5: string (nullable = true)
#  |-- QID18: string (nullable = true)
#  |-- QID19_1: string (nullable = true)
#  |-- QID19_2: string (nullable = true)
#  |-- QID19_3: string (nullable = true)
#  |-- QID2: string (nullable = true)
#  |-- QID21_1: string (nullable = true)
#  |-- QID21_2: string (nullable = true)
#  |-- QID21_3: string (nullable = true)
#  |-- QID21_4: string (nullable = true)
#  |-- QID21_5: string (nullable = true)
#  |-- QID21_6: string (nullable = true)
#  |-- QID21_7: string (nullable = true)
#  |-- QID23: string (nullable = true)
#  |-- QID24_1: string (nullable = true)
#  |-- QID24_2: string (nullable = true)
#  |-- QID24_3: string (nullable = true)
#  |-- QID24_4: string (nullable = true)
#  |-- QID24_5: string (nullable = true)
#  |-- QID27: string (nullable = true)
#  |-- QID28_1: string (nullable = true)
#  |-- QID28_2: string (nullable = true)
#  |-- QID28_3: string (nullable = true)
#  |-- QID28_4: string (nullable = true)
#  |-- QID28_5: string (nullable = true)
#  |-- QID28_6: string (nullable = true)
#  |-- QID28_7: string (nullable = true)
#  |-- QID28_8: string (nullable = true)
#  |-- QID3: string (nullable = true)
#  |-- QID33: string (nullable = true)
#  |-- QID34: string (nullable = true)
#  |-- QID35_1: string (nullable = true)
#  |-- QID35_2: string (nullable = true)
#  |-- QID35_3: string (nullable = true)
#  |-- QID35_4: string (nullable = true)
#  |-- QID35_5: string (nullable = true)
#  |-- QID35_6: string (nullable = true)
#  |-- QID35_7: string (nullable = true)
#  |-- QID35_9: string (nullable = true)
#  |-- QID37: string (nullable = true)
#  |-- QID38_1: string (nullable = true)
#  |-- QID38_2: string (nullable = true)
#  |-- QID38_3: string (nullable = true)
#  |-- QID38_5: string (nullable = true)
#  |-- QID4: string (nullable = true)
#  |-- QID40: string (nullable = true)
#  |-- QID41_1: string (nullable = true)
#  |-- QID41_2: string (nullable = true)
#  |-- QID41_3: string (nullable = true)
#  |-- QID41_4: string (nullable = true)
#  |-- QID41_5: string (nullable = true)
#  |-- QID41_6: string (nullable = true)
#  |-- QID41_7: string (nullable = true)
#  |-- QID41_8: string (nullable = true)
#  |-- QID42: string (nullable = true)
#  |-- QID47: string (nullable = true)
#  |-- QID48: string (nullable = true)
#  |-- QID5: string (nullable = true)
#  |-- QID7_1: string (nullable = true)
#  |-- QID7_2: string (nullable = true)
#  |-- QID7_3: string (nullable = true)
#  |-- QID7_4: string (nullable = true)
#  |-- QID7_5: string (nullable = true)
#  |-- QID7_6: string (nullable = true)
#  |-- QID7_7: string (nullable = true)
#  |-- QID7_8: string (nullable = true)
#  |-- QID9: string (nullable = true)
#  |-- QID94: string (nullable = true)
#  |-- finished: string (nullable = true)
#  |-- status: string (nullable = true)

# %%
df_arrays = df_labels[[f.name for f in df_labels.schema.fields if isinstance(f.dataType, T.ArrayType)]].dropDuplicates()
display(df_arrays.toPandas())

# %%
# converting the array columns to String 

# get array columns
array_columns = [f.name for f in df_labels.schema.fields if isinstance(f.dataType, T.ArrayType)]

# concat_ws to convery array columns to comma-separated string
for col_name in array_columns:
    df_labels = df_labels.withColumn(
        col_name, 
        F.array_join(
            F.col(col_name),
            ","
        )
    )

df_labels.printSchema()
# Out:
# root
#  |-- responseId: string (nullable = true)
#  |-- QID101: string (nullable = true)
#  |-- QID103_1: string (nullable = true)
#  |-- QID103_2: string (nullable = true)
#  |-- QID103_3: string (nullable = true)
#  |-- QID103_4: string (nullable = true)
#  |-- QID103_5: string (nullable = true)
#  |-- QID103_6: string (nullable = true)
#  |-- QID103_7: string (nullable = true)
#  |-- QID103_8: string (nullable = true)
#  |-- QID103_9: string (nullable = true)
#  |-- QID106: string (nullable = true)
#  |-- QID107: string (nullable = true)
#  |-- QID108: string (nullable = true)
#  |-- QID10_1: string (nullable = true)
#  |-- QID10_2: string (nullable = true)
#  |-- QID10_3: string (nullable = true)
#  |-- QID10_4: string (nullable = true)
#  |-- QID10_5: string (nullable = true)
#  |-- QID10_6: string (nullable = true)
#  |-- QID119: string (nullable = true)
#  |-- QID12: string (nullable = true)
#  |-- QID120_1: string (nullable = true)
#  |-- QID120_2: string (nullable = true)
#  |-- QID120_3: string (nullable = true)
#  |-- QID120_4: string (nullable = true)
#  |-- QID120_5: string (nullable = true)
#  |-- QID120_6: string (nullable = true)
#  |-- QID120_7: string (nullable = true)
#  |-- QID120_8: string (nullable = true)
#  |-- QID128: string (nullable = true)
#  |-- QID130_1: string (nullable = true)
#  |-- QID130_10: string (nullable = true)
#  |-- QID130_2: string (nullable = true)
#  |-- QID130_3: string (nullable = true)
#  |-- QID130_4: string (nullable = true)
#  |-- QID130_6: string (nullable = true)
#  |-- QID130_7: string (nullable = true)
#  |-- QID130_8: string (nullable = true)
#  |-- QID130_9: string (nullable = true)
#  |-- QID133: string (nullable = true)
#  |-- QID135: string (nullable = true)
#  |-- QID137_1: string (nullable = true)
#  |-- QID137_2: string (nullable = true)
#  |-- QID137_3: string (nullable = true)
#  |-- QID137_4: string (nullable = true)
#  |-- QID137_5: string (nullable = true)
#  |-- QID137_6: string (nullable = true)
#  |-- QID137_7: string (nullable = true)
#  |-- QID137_8: string (nullable = true)
#  |-- QID138: string (nullable = true)
#  |-- QID13_1: string (nullable = true)
#  |-- QID13_2: string (nullable = true)
#  |-- QID13_3: string (nullable = true)
#  |-- QID13_4: string (nullable = true)
#  |-- QID13_5: string (nullable = true)
#  |-- QID13_6: string (nullable = true)
#  |-- QID13_7: string (nullable = true)
#  |-- QID13_8: string (nullable = true)
#  |-- QID144: string (nullable = true)
#  |-- QID145_1: string (nullable = true)
#  |-- QID145_2: string (nullable = true)
#  |-- QID145_3: string (nullable = true)
#  |-- QID145_5: string (nullable = true)
#  |-- QID145_9: string (nullable = true)
#  |-- QID146: string (nullable = true)
#  |-- QID149: string (nullable = true)
#  |-- QID15: string (nullable = true)
#  |-- QID16_1: string (nullable = true)
#  |-- QID16_2: string (nullable = true)
#  |-- QID16_3: string (nullable = true)
#  |-- QID16_4: string (nullable = true)
#  |-- QID16_5: string (nullable = true)
#  |-- QID18: string (nullable = true)
#  |-- QID19_1: string (nullable = true)
#  |-- QID19_2: string (nullable = true)
#  |-- QID19_3: string (nullable = true)
#  |-- QID2: string (nullable = true)
#  |-- QID21_1: string (nullable = true)
#  |-- QID21_2: string (nullable = true)
#  |-- QID21_3: string (nullable = true)
#  |-- QID21_4: string (nullable = true)
#  |-- QID21_5: string (nullable = true)
#  |-- QID21_6: string (nullable = true)
#  |-- QID21_7: string (nullable = true)
#  |-- QID23: string (nullable = true)
#  |-- QID24_1: string (nullable = true)
#  |-- QID24_2: string (nullable = true)
#  |-- QID24_3: string (nullable = true)
#  |-- QID24_4: string (nullable = true)
#  |-- QID24_5: string (nullable = true)
#  |-- QID27: string (nullable = true)
#  |-- QID28_1: string (nullable = true)
#  |-- QID28_2: string (nullable = true)
#  |-- QID28_3: string (nullable = true)
#  |-- QID28_4: string (nullable = true)
#  |-- QID28_5: string (nullable = true)
#  |-- QID28_6: string (nullable = true)
#  |-- QID28_7: string (nullable = true)
#  |-- QID28_8: string (nullable = true)
#  |-- QID3: string (nullable = true)
#  |-- QID33: string (nullable = true)
#  |-- QID34: string (nullable = true)
#  |-- QID35_1: string (nullable = true)
#  |-- QID35_2: string (nullable = true)
#  |-- QID35_3: string (nullable = true)
#  |-- QID35_4: string (nullable = true)
#  |-- QID35_5: string (nullable = true)
#  |-- QID35_6: string (nullable = true)
#  |-- QID35_7: string (nullable = true)
#  |-- QID35_9: string (nullable = true)
#  |-- QID37: string (nullable = true)
#  |-- QID38_1: string (nullable = true)
#  |-- QID38_2: string (nullable = true)
#  |-- QID38_3: string (nullable = true)
#  |-- QID38_5: string (nullable = true)
#  |-- QID4: string (nullable = true)
#  |-- QID40: string (nullable = true)
#  |-- QID41_1: string (nullable = true)
#  |-- QID41_2: string (nullable = true)
#  |-- QID41_3: string (nullable = true)
#  |-- QID41_4: string (nullable = true)
#  |-- QID41_5: string (nullable = true)
#  |-- QID41_6: string (nullable = true)
#  |-- QID41_7: string (nullable = true)
#  |-- QID41_8: string (nullable = true)
#  |-- QID42: string (nullable = true)
#  |-- QID47: string (nullable = true)
#  |-- QID48: string (nullable = true)
#  |-- QID5: string (nullable = true)
#  |-- QID7_1: string (nullable = true)
#  |-- QID7_2: string (nullable = true)
#  |-- QID7_3: string (nullable = true)
#  |-- QID7_4: string (nullable = true)
#  |-- QID7_5: string (nullable = true)
#  |-- QID7_6: string (nullable = true)
#  |-- QID7_7: string (nullable = true)
#  |-- QID7_8: string (nullable = true)
#  |-- QID9: string (nullable = true)
#  |-- QID94: string (nullable = true)
#  |-- finished: string (nullable = true)
#  |-- status: string (nullable = true)

# %%
# validate one of the array columns to ensure conversion to string didn't remove the data
df_labels.select(F.col("QID146")).filter(F.col("QID146").isNotNull()).show(truncate=False)

# %%
df_labels_renamed = df_labels.select(
    [F.col(c).alias(c + "_label") for c in df_labels.columns]
).withColumnRenamed("responseId_label", "responseId") # remove suffix from responseId column
df_labels_renamed.printSchema()
# Out:
# root
#  |-- responseId: string (nullable = true)
#  |-- QID101_label: string (nullable = true)
#  |-- QID103_1_label: string (nullable = true)
#  |-- QID103_2_label: string (nullable = true)
#  |-- QID103_3_label: string (nullable = true)
#  |-- QID103_4_label: string (nullable = true)
#  |-- QID103_5_label: string (nullable = true)
#  |-- QID103_6_label: string (nullable = true)
#  |-- QID103_7_label: string (nullable = true)
#  |-- QID103_8_label: string (nullable = true)
#  |-- QID103_9_label: string (nullable = true)
#  |-- QID106_label: string (nullable = true)
#  |-- QID107_label: string (nullable = true)
#  |-- QID108_label: string (nullable = true)
#  |-- QID10_1_label: string (nullable = true)
#  |-- QID10_2_label: string (nullable = true)
#  |-- QID10_3_label: string (nullable = true)
#  |-- QID10_4_label: string (nullable = true)
#  |-- QID10_5_label: string (nullable = true)
#  |-- QID10_6_label: string (nullable = true)
#  |-- QID119_label: string (nullable = true)
#  |-- QID12_label: string (nullable = true)
#  |-- QID120_1_label: string (nullable = true)
#  |-- QID120_2_label: string (nullable = true)
#  |-- QID120_3_label: string (nullable = true)
#  |-- QID120_4_label: string (nullable = true)
#  |-- QID120_5_label: string (nullable = true)
#  |-- QID120_6_label: string (nullable = true)
#  |-- QID120_7_label: string (nullable = true)
#  |-- QID120_8_label: string (nullable = true)
#  |-- QID128_label: string (nullable = true)
#  |-- QID130_1_label: string (nullable = true)
#  |-- QID130_10_label: string (nullable = true)
#  |-- QID130_2_label: string (nullable = true)
#  |-- QID130_3_label: string (nullable = true)
#  |-- QID130_4_label: string (nullable = true)
#  |-- QID130_6_label: string (nullable = true)
#  |-- QID130_7_label: string (nullable = true)
#  |-- QID130_8_label: string (nullable = true)
#  |-- QID130_9_label: string (nullable = true)
#  |-- QID133_label: string (nullable = true)
#  |-- QID135_label: string (nullable = true)
#  |-- QID137_1_label: string (nullable = true)
#  |-- QID137_2_label: string (nullable = true)
#  |-- QID137_3_label: string (nullable = true)
#  |-- QID137_4_label: string (nullable = true)
#  |-- QID137_5_label: string (nullable = true)
#  |-- QID137_6_label: string (nullable = true)
#  |-- QID137_7_label: string (nullable = true)
#  |-- QID137_8_label: string (nullable = true)
#  |-- QID138_label: string (nullable = true)
#  |-- QID13_1_label: string (nullable = true)
#  |-- QID13_2_label: string (nullable = true)
#  |-- QID13_3_label: string (nullable = true)
#  |-- QID13_4_label: string (nullable = true)
#  |-- QID13_5_label: string (nullable = true)
#  |-- QID13_6_label: string (nullable = true)
#  |-- QID13_7_label: string (nullable = true)
#  |-- QID13_8_label: string (nullable = true)
#  |-- QID144_label: string (nullable = true)
#  |-- QID145_1_label: string (nullable = true)
#  |-- QID145_2_label: string (nullable = true)
#  |-- QID145_3_label: string (nullable = true)
#  |-- QID145_5_label: string (nullable = true)
#  |-- QID145_9_label: string (nullable = true)
#  |-- QID146_label: string (nullable = true)
#  |-- QID149_label: string (nullable = true)
#  |-- QID15_label: string (nullable = true)
#  |-- QID16_1_label: string (nullable = true)
#  |-- QID16_2_label: string (nullable = true)
#  |-- QID16_3_label: string (nullable = true)
#  |-- QID16_4_label: string (nullable = true)
#  |-- QID16_5_label: string (nullable = true)
#  |-- QID18_label: string (nullable = true)
#  |-- QID19_1_label: string (nullable = true)
#  |-- QID19_2_label: string (nullable = true)
#  |-- QID19_3_label: string (nullable = true)
#  |-- QID2_label: string (nullable = true)
#  |-- QID21_1_label: string (nullable = true)
#  |-- QID21_2_label: string (nullable = true)
#  |-- QID21_3_label: string (nullable = true)
#  |-- QID21_4_label: string (nullable = true)
#  |-- QID21_5_label: string (nullable = true)
#  |-- QID21_6_label: string (nullable = true)
#  |-- QID21_7_label: string (nullable = true)
#  |-- QID23_label: string (nullable = true)
#  |-- QID24_1_label: string (nullable = true)
#  |-- QID24_2_label: string (nullable = true)
#  |-- QID24_3_label: string (nullable = true)
#  |-- QID24_4_label: string (nullable = true)
#  |-- QID24_5_label: string (nullable = true)
#  |-- QID27_label: string (nullable = true)
#  |-- QID28_1_label: string (nullable = true)
#  |-- QID28_2_label: string (nullable = true)
#  |-- QID28_3_label: string (nullable = true)
#  |-- QID28_4_label: string (nullable = true)
#  |-- QID28_5_label: string (nullable = true)
#  |-- QID28_6_label: string (nullable = true)
#  |-- QID28_7_label: string (nullable = true)
#  |-- QID28_8_label: string (nullable = true)
#  |-- QID3_label: string (nullable = true)
#  |-- QID33_label: string (nullable = true)
#  |-- QID34_label: string (nullable = true)
#  |-- QID35_1_label: string (nullable = true)
#  |-- QID35_2_label: string (nullable = true)
#  |-- QID35_3_label: string (nullable = true)
#  |-- QID35_4_label: string (nullable = true)
#  |-- QID35_5_label: string (nullable = true)
#  |-- QID35_6_label: string (nullable = true)
#  |-- QID35_7_label: string (nullable = true)
#  |-- QID35_9_label: string (nullable = true)
#  |-- QID37_label: string (nullable = true)
#  |-- QID38_1_label: string (nullable = true)
#  |-- QID38_2_label: string (nullable = true)
#  |-- QID38_3_label: string (nullable = true)
#  |-- QID38_5_label: string (nullable = true)
#  |-- QID4_label: string (nullable = true)
#  |-- QID40_label: string (nullable = true)
#  |-- QID41_1_label: string (nullable = true)
#  |-- QID41_2_label: string (nullable = true)
#  |-- QID41_3_label: string (nullable = true)
#  |-- QID41_4_label: string (nullable = true)
#  |-- QID41_5_label: string (nullable = true)
#  |-- QID41_6_label: string (nullable = true)
#  |-- QID41_7_label: string (nullable = true)
#  |-- QID41_8_label: string (nullable = true)
#  |-- QID42_label: string (nullable = true)
#  |-- QID47_label: string (nullable = true)
#  |-- QID48_label: string (nullable = true)
#  |-- QID5_label: string (nullable = true)
#  |-- QID7_1_label: string (nullable = true)
#  |-- QID7_2_label: string (nullable = true)
#  |-- QID7_3_label: string (nullable = true)
#  |-- QID7_4_label: string (nullable = true)
#  |-- QID7_5_label: string (nullable = true)
#  |-- QID7_6_label: string (nullable = true)
#  |-- QID7_7_label: string (nullable = true)
#  |-- QID7_8_label: string (nullable = true)
#  |-- QID9_label: string (nullable = true)
#  |-- QID94_label: string (nullable = true)
#  |-- finished_label: string (nullable = true)
#  |-- status_label: string (nullable = true)

# %%
df_final = df_values.join(df_labels_renamed, "responseId", "left")
df_final = df_final.select(sorted(df_final.columns))
df_final.printSchema()
# Out:
# root
#  |-- AccountName: string (nullable = true)
#  |-- AccountName_5e02b1554bfe4b0dac61f801SenPol: long (nullable = true)
#  |-- AccountName_5e02b1554bfe4b0dac61f801SenScore: long (nullable = true)
#  |-- BPCode: string (nullable = true)
#  |-- COVIDComments: string (nullable = true)
#  |-- CRMLink: string (nullable = true)
#  |-- CRMOwner: string (nullable = true)
#  |-- CRMOwnerEmail: string (nullable = true)
#  |-- ContactArea: string (nullable = true)
#  |-- ContactAreaCode: string (nullable = true)
#  |-- ContactCountry: string (nullable = true)
#  |-- ContactCountryCode: string (nullable = true)
#  |-- ContactEmail: string (nullable = true)
#  |-- ContactName: string (nullable = true)
#  |-- CustomerType: string (nullable = true)
#  |-- Digital: string (nullable = true)
#  |-- Distinction: string (nullable = true)
#  |-- GlobalCode: string (nullable = true)
#  |-- GlobalName: string (nullable = true)
#  |-- Guide: string (nullable = true)
#  |-- LST: string (nullable = true)
#  |-- OwnerArea: string (nullable = true)
#  |-- OwnerAreaCode: string (nullable = true)
#  |-- OwnerCountry: string (nullable = true)
#  |-- OwnerCountryCode: string (nullable = true)
#  |-- PrimaryBusiness: string (nullable = true)
#  |-- PrimaryBusinessGroup: string (nullable = true)
#  |-- PrimaryMajorMarket: string (nullable = true)
#  |-- QID101: long (nullable = true)
#  |-- QID101_label: string (nullable = true)
#  |-- QID103_1: long (nullable = true)
#  |-- QID103_1_label: string (nullable = true)
#  |-- QID103_2: long (nullable = true)
#  |-- QID103_2_label: string (nullable = true)
#  |-- QID103_3: long (nullable = true)
#  |-- QID103_3_label: string (nullable = true)
#  |-- QID103_4: long (nullable = true)
#  |-- QID103_4_label: string (nullable = true)
#  |-- QID103_5: long (nullable = true)
#  |-- QID103_5_label: string (nullable = true)
#  |-- QID103_6: long (nullable = true)
#  |-- QID103_6_label: string (nullable = true)
#  |-- QID103_7: long (nullable = true)
#  |-- QID103_7_label: string (nullable = true)
#  |-- QID103_8: long (nullable = true)
#  |-- QID103_8_label: string (nullable = true)
#  |-- QID103_9: long (nullable = true)
#  |-- QID103_9_label: string (nullable = true)
#  |-- QID105_TEXT: string (nullable = true)
#  |-- QID106: long (nullable = true)
#  |-- QID106_label: string (nullable = true)
#  |-- QID107: long (nullable = true)
#  |-- QID107_label: string (nullable = true)
#  |-- QID108: long (nullable = true)
#  |-- QID108_label: string (nullable = true)
#  |-- QID10_1: long (nullable = true)
#  |-- QID10_1_label: string (nullable = true)
#  |-- QID10_2: long (nullable = true)
#  |-- QID10_2_label: string (nullable = true)
#  |-- QID10_3: long (nullable = true)
#  |-- QID10_3_label: string (nullable = true)
#  |-- QID10_4: long (nullable = true)
#  |-- QID10_4_label: string (nullable = true)
#  |-- QID10_5: long (nullable = true)
#  |-- QID10_5_label: string (nullable = true)
#  |-- QID10_6: long (nullable = true)
#  |-- QID10_6_label: string (nullable = true)
#  |-- QID119: long (nullable = true)
#  |-- QID119_label: string (nullable = true)
#  |-- QID11_TEXT: string (nullable = true)
#  |-- QID11_TEXT_TRANSLATEDen93ihhyq: string (nullable = true)
#  |-- QID12: long (nullable = true)
#  |-- QID120_1: long (nullable = true)
#  |-- QID120_1_label: string (nullable = true)
#  |-- QID120_2: long (nullable = true)
#  |-- QID120_2_label: string (nullable = true)
#  |-- QID120_3: long (nullable = true)
#  |-- QID120_3_label: string (nullable = true)
#  |-- QID120_4: long (nullable = true)
#  |-- QID120_4_label: string (nullable = true)
#  |-- QID120_5: long (nullable = true)
#  |-- QID120_5_label: string (nullable = true)
#  |-- QID120_6: long (nullable = true)
#  |-- QID120_6_label: string (nullable = true)
#  |-- QID120_7: long (nullable = true)
#  |-- QID120_7_label: string (nullable = true)
#  |-- QID120_8: long (nullable = true)
#  |-- QID120_8_label: string (nullable = true)
#  |-- QID121_TEXT: string (nullable = true)
#  |-- QID128: long (nullable = true)
#  |-- QID128_label: string (nullable = true)
#  |-- QID12_label: string (nullable = true)
#  |-- QID130_1: long (nullable = true)
#  |-- QID130_10: long (nullable = true)
#  |-- QID130_10_label: string (nullable = true)
#  |-- QID130_1_label: string (nullable = true)
#  |-- QID130_2: long (nullable = true)
#  |-- QID130_2_label: string (nullable = true)
#  |-- QID130_3: long (nullable = true)
#  |-- QID130_3_label: string (nullable = true)
#  |-- QID130_4: long (nullable = true)
#  |-- QID130_4_label: string (nullable = true)
#  |-- QID130_6: long (nullable = true)
#  |-- QID130_6_label: string (nullable = true)
#  |-- QID130_7: long (nullable = true)
#  |-- QID130_7_label: string (nullable = true)
#  |-- QID130_8: long (nullable = true)
#  |-- QID130_8_label: string (nullable = true)
#  |-- QID130_9: long (nullable = true)
#  |-- QID130_9_label: string (nullable = true)
#  |-- QID131_TEXT: string (nullable = true)
#  |-- QID131_TEXT_TRANSLATEDenn363j8m: string (nullable = true)
#  |-- QID133: long (nullable = true)
#  |-- QID133_label: string (nullable = true)
#  |-- QID135: long (nullable = true)
#  |-- QID135_3_TEXT: string (nullable = true)
#  |-- QID135_3_TEXT_TRANSLATEDen8wvxb4h: string (nullable = true)
#  |-- QID135_label: string (nullable = true)
#  |-- QID137_1: long (nullable = true)
#  |-- QID137_1_label: string (nullable = true)
#  |-- QID137_2: long (nullable = true)
#  |-- QID137_2_label: string (nullable = true)
#  |-- QID137_3: long (nullable = true)
#  |-- QID137_3_label: string (nullable = true)
#  |-- QID137_4: long (nullable = true)
#  |-- QID137_4_label: string (nullable = true)
#  |-- QID137_5: long (nullable = true)
#  |-- QID137_5_label: string (nullable = true)
#  |-- QID137_6: long (nullable = true)
#  |-- QID137_6_label: string (nullable = true)
#  |-- QID137_7: long (nullable = true)
#  |-- QID137_7_label: string (nullable = true)
#  |-- QID137_8: long (nullable = true)
#  |-- QID137_8_label: string (nullable = true)
#  |-- QID138: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID138_label: string (nullable = true)
#  |-- QID139_TEXT: string (nullable = true)
#  |-- QID139_TEXT_TRANSLATEDen8qtubni: string (nullable = true)
#  |-- QID13_1: long (nullable = true)
#  |-- QID13_1_label: string (nullable = true)
#  |-- QID13_2: long (nullable = true)
#  |-- QID13_2_label: string (nullable = true)
#  |-- QID13_3: long (nullable = true)
#  |-- QID13_3_label: string (nullable = true)
#  |-- QID13_4: long (nullable = true)
#  |-- QID13_4_label: string (nullable = true)
#  |-- QID13_5: long (nullable = true)
#  |-- QID13_5_label: string (nullable = true)
#  |-- QID13_6: long (nullable = true)
#  |-- QID13_6_label: string (nullable = true)
#  |-- QID13_7: long (nullable = true)
#  |-- QID13_7_label: string (nullable = true)
#  |-- QID13_8: long (nullable = true)
#  |-- QID13_8_label: string (nullable = true)
#  |-- QID142_BROWSER: string (nullable = true)
#  |-- QID142_OS: string (nullable = true)
#  |-- QID142_RESOLUTION: string (nullable = true)
#  |-- QID142_VERSION: string (nullable = true)
#  |-- QID143_9_TEXT_TRANSLATEDenqvga6ad: string (nullable = true)
#  |-- QID144: long (nullable = true)
#  |-- QID144_label: string (nullable = true)
#  |-- QID145_1: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_1_label: string (nullable = true)
#  |-- QID145_2: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_2_label: string (nullable = true)
#  |-- QID145_3: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_3_label: string (nullable = true)
#  |-- QID145_5: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_5_label: string (nullable = true)
#  |-- QID145_9: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID145_9_TEXT: string (nullable = true)
#  |-- QID145_9_TEXT_TRANSLATEDen5op1zyu: string (nullable = true)
#  |-- QID145_9_label: string (nullable = true)
#  |-- QID146: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- QID146_9_TEXT: string (nullable = true)
#  |-- QID146_9_TEXT_TRANSLATEDenl7jzo6e: string (nullable = true)
#  |-- QID146_label: string (nullable = true)
#  |-- QID149: long (nullable = true)
#  |-- QID149_label: string (nullable = true)
#  |-- QID14_TEXT: string (nullable = true)
#  |-- QID14_TEXT_5e02b1554bfe4b0dac61f801SenPol: long (nullable = true)
#  |-- QID14_TEXT_5e02b1554bfe4b0dac61f801SenScore: long (nullable = true)
#  |-- QID14_TEXT_TRANSLATEDenwohlzuj: string (nullable = true)
#  |-- QID15: long (nullable = true)
#  |-- QID15_label: string (nullable = true)
#  |-- QID16_1: long (nullable = true)
#  |-- QID16_1_label: string (nullable = true)
#  |-- QID16_2: long (nullable = true)
#  |-- QID16_2_label: string (nullable = true)
#  |-- QID16_3: long (nullable = true)
#  |-- QID16_3_label: string (nullable = true)
#  |-- QID16_4: long (nullable = true)
#  |-- QID16_4_label: string (nullable = true)
#  |-- QID16_5: long (nullable = true)
#  |-- QID16_5_label: string (nullable = true)
#  |-- QID17_TEXT: string (nullable = true)
#  |-- QID17_TEXT_TRANSLATEDenre9rccw: string (nullable = true)
#  |-- QID18: long (nullable = true)
#  |-- QID18_label: string (nullable = true)
#  |-- QID19_1: long (nullable = true)
#  |-- QID19_1_label: string (nullable = true)
#  |-- QID19_2: long (nullable = true)
#  |-- QID19_2_label: string (nullable = true)
#  |-- QID19_3: long (nullable = true)
#  |-- QID19_3_label: string (nullable = true)
#  |-- QID2: long (nullable = true)
#  |-- QID20_TEXT: string (nullable = true)
#  |-- QID20_TEXT_TRANSLATEDen1ao9nhu: string (nullable = true)
#  |-- QID21_1: long (nullable = true)
#  |-- QID21_1_label: string (nullable = true)
#  |-- QID21_2: long (nullable = true)
#  |-- QID21_2_label: string (nullable = true)
#  |-- QID21_3: long (nullable = true)
#  |-- QID21_3_label: string (nullable = true)
#  |-- QID21_4: long (nullable = true)
#  |-- QID21_4_label: string (nullable = true)
#  |-- QID21_5: long (nullable = true)
#  |-- QID21_5_label: string (nullable = true)
#  |-- QID21_6: long (nullable = true)
#  |-- QID21_6_label: string (nullable = true)
#  |-- QID21_7: long (nullable = true)
#  |-- QID21_7_label: string (nullable = true)
#  |-- QID22_TEXT: string (nullable = true)
#  |-- QID22_TEXT_TRANSLATEDens1qb5u1: string (nullable = true)
#  |-- QID23: long (nullable = true)
#  |-- QID23_label: string (nullable = true)
#  |-- QID24_1: long (nullable = true)
#  |-- QID24_1_label: string (nullable = true)
#  |-- QID24_2: long (nullable = true)
#  |-- QID24_2_label: string (nullable = true)
#  |-- QID24_3: long (nullable = true)
#  |-- QID24_3_label: string (nullable = true)
#  |-- QID24_4: long (nullable = true)
#  |-- QID24_4_label: string (nullable = true)
#  |-- QID24_5: long (nullable = true)
#  |-- QID24_5_label: string (nullable = true)
#  |-- QID25_TEXT: string (nullable = true)
#  |-- QID25_TEXT_TRANSLATEDenly9xu00: string (nullable = true)
#  |-- QID27: long (nullable = true)
#  |-- QID27_label: string (nullable = true)
#  |-- QID28_1: long (nullable = true)
#  |-- QID28_1_label: string (nullable = true)
#  |-- QID28_2: long (nullable = true)
#  |-- QID28_2_label: string (nullable = true)
#  |-- QID28_3: long (nullable = true)
#  |-- QID28_3_label: string (nullable = true)
#  |-- QID28_4: long (nullable = true)
#  |-- QID28_4_label: string (nullable = true)
#  |-- QID28_5: long (nullable = true)
#  |-- QID28_5_label: string (nullable = true)
#  |-- QID28_6: long (nullable = true)
#  |-- QID28_6_label: string (nullable = true)
#  |-- QID28_7: long (nullable = true)
#  |-- QID28_7_label: string (nullable = true)
#  |-- QID28_8: long (nullable = true)
#  |-- QID28_8_label: string (nullable = true)
#  |-- QID29_TEXT: string (nullable = true)
#  |-- QID29_TEXT_TRANSLATEDenwvw39mf: string (nullable = true)
#  |-- QID2_5_TEXT: string (nullable = true)
#  |-- QID2_5_TEXT_TRANSLATEDenekufezj: string (nullable = true)
#  |-- QID2_label: string (nullable = true)
#  |-- QID3: long (nullable = true)
#  |-- QID33: long (nullable = true)
#  |-- QID33_label: string (nullable = true)
#  |-- QID34: long (nullable = true)
#  |-- QID34_label: string (nullable = true)
#  |-- QID35_1: long (nullable = true)
#  |-- QID35_1_label: string (nullable = true)
#  |-- QID35_2: long (nullable = true)
#  |-- QID35_2_label: string (nullable = true)
#  |-- QID35_3: long (nullable = true)
#  |-- QID35_3_label: string (nullable = true)
#  |-- QID35_4: long (nullable = true)
#  |-- QID35_4_label: string (nullable = true)
#  |-- QID35_5: long (nullable = true)
#  |-- QID35_5_label: string (nullable = true)
#  |-- QID35_6: long (nullable = true)
#  |-- QID35_6_label: string (nullable = true)
#  |-- QID35_7: long (nullable = true)
#  |-- QID35_7_label: string (nullable = true)
#  |-- QID35_9: long (nullable = true)
#  |-- QID35_9_label: string (nullable = true)
#  |-- QID36_TEXT: string (nullable = true)
#  |-- QID36_TEXT_TRANSLATEDen6kfua67: string (nullable = true)
#  |-- QID37: long (nullable = true)
#  |-- QID37_label: string (nullable = true)
#  |-- QID38_1: long (nullable = true)
#  |-- QID38_1_label: string (nullable = true)
#  |-- QID38_2: long (nullable = true)
#  |-- QID38_2_label: string (nullable = true)
#  |-- QID38_3: long (nullable = true)
#  |-- QID38_3_label: string (nullable = true)
#  |-- QID38_5: long (nullable = true)
#  |-- QID38_5_label: string (nullable = true)
#  |-- QID39_TEXT: string (nullable = true)
#  |-- QID39_TEXT_TRANSLATEDeni4c8ssx: string (nullable = true)
#  |-- QID3_label: string (nullable = true)
#  |-- QID4: long (nullable = true)
#  |-- QID40: long (nullable = true)
#  |-- QID40_label: string (nullable = true)
#  |-- QID41_1: long (nullable = true)
#  |-- QID41_1_label: string (nullable = true)
#  |-- QID41_2: long (nullable = true)
#  |-- QID41_2_label: string (nullable = true)
#  |-- QID41_3: long (nullable = true)
#  |-- QID41_3_label: string (nullable = true)
#  |-- QID41_4: long (nullable = true)
#  |-- QID41_4_label: string (nullable = true)
#  |-- QID41_5: long (nullable = true)
#  |-- QID41_5_label: string (nullable = true)
#  |-- QID41_6: long (nullable = true)
#  |-- QID41_6_label: string (nullable = true)
#  |-- QID41_7: long (nullable = true)
#  |-- QID41_7_label: string (nullable = true)
#  |-- QID41_8: long (nullable = true)
#  |-- QID41_8_label: string (nullable = true)
#  |-- QID42: long (nullable = true)
#  |-- QID42_label: string (nullable = true)
#  |-- QID43_TEXT: string (nullable = true)
#  |-- QID43_TEXT_TRANSLATEDenu8vx5gc: string (nullable = true)
#  |-- QID44_TEXT: string (nullable = true)
#  |-- QID44_TEXT_TRANSLATEDen6m3495e: string (nullable = true)
#  |-- QID47: long (nullable = true)
#  |-- QID47_label: string (nullable = true)
#  |-- QID48: long (nullable = true)
#  |-- QID48_label: string (nullable = true)
#  |-- QID49_TEXT: string (nullable = true)
#  |-- QID49_TEXT_TRANSLATEDeni0zgv8j: string (nullable = true)
#  |-- QID4_label: string (nullable = true)
#  |-- QID5: long (nullable = true)
#  |-- QID50_TEXT: string (nullable = true)
#  |-- QID50_TEXT_TRANSLATEDen10pb0wp: string (nullable = true)
#  |-- QID5_label: string (nullable = true)
#  |-- QID6_TEXT: string (nullable = true)
#  |-- QID6_TEXT_TRANSLATEDena6a9kkj: string (nullable = true)
#  |-- QID7_1: long (nullable = true)
#  |-- QID7_1_label: string (nullable = true)
#  |-- QID7_2: long (nullable = true)
#  |-- QID7_2_label: string (nullable = true)
#  |-- QID7_3: long (nullable = true)
#  |-- QID7_3_label: string (nullable = true)
#  |-- QID7_4: long (nullable = true)
#  |-- QID7_4_label: string (nullable = true)
#  |-- QID7_5: long (nullable = true)
#  |-- QID7_5_label: string (nullable = true)
#  |-- QID7_6: long (nullable = true)
#  |-- QID7_6_label: string (nullable = true)
#  |-- QID7_7: long (nullable = true)
#  |-- QID7_7_label: string (nullable = true)
#  |-- QID7_8: long (nullable = true)
#  |-- QID7_8_label: string (nullable = true)
#  |-- QID8_TEXT: string (nullable = true)
#  |-- QID8_TEXT_TRANSLATEDenue1spzz: string (nullable = true)
#  |-- QID9: long (nullable = true)
#  |-- QID94: long (nullable = true)
#  |-- QID94_label: string (nullable = true)
#  |-- QID9_label: string (nullable = true)
#  |-- Q_Language: string (nullable = true)
#  |-- Quarter: string (nullable = true)
#  |-- QuarterRollup: string (nullable = true)
#  |-- QuarterYear: string (nullable = true)
#  |-- Randomized_ID: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- SalName: string (nullable = true)
#  |-- Score: string (nullable = true)
#  |-- SellerEmail: string (nullable = true)
#  |-- SellerEmailSSO: string (nullable = true)
#  |-- SellerName: string (nullable = true)
#  |-- StrategicName: string (nullable = true)
#  |-- Submit: string (nullable = true)
#  |-- SustainabilityLanguageFilter: string (nullable = true)
#  |-- Year: string (nullable = true)
#  |-- _recordId: string (nullable = true)
#  |-- distributionChannel: string (nullable = true)
#  |-- duration: long (nullable = true)
#  |-- endDate: string (nullable = true)
#  |-- finished: long (nullable = true)
#  |-- finished_label: string (nullable = true)
#  |-- ipAddress: string (nullable = true)
#  |-- locationLatitude: string (nullable = true)
#  |-- locationLongitude: string (nullable = true)
#  |-- progress: long (nullable = true)
#  |-- recipientEmail: string (nullable = true)
#  |-- recipientFirstName: string (nullable = true)
#  |-- recipientLastName: string (nullable = true)
#  |-- recordedDate: string (nullable = true)
#  |-- responseId: string (nullable = true)
#  |-- startDate: string (nullable = true)
#  |-- status: long (nullable = true)
#  |-- status_label: string (nullable = true)
#  |-- userLanguage: string (nullable = true)

# %%
display(df_final.toPandas())
# Out:
#                              AccountName  \
# 0         XINA OPERATIONS AND MAINTENANC
# 1                      BENVIC EUROPE SAS
# 2                   ECOPLAST PLASTIK AMB
# 3                       ENTEGRE HARC A S
# 4                      ADAMIETZ SP Z O O
# ...                                  ...
# 40449                             TEKNOS
# 40450              MICROPLAST - MEDELLIN
# 40451  INGERSOLL-RAND INDUSTRIAL IRELAND
# 40452                   YONG FUN TRADING
# 40453                  CEMBRIT GROUP A S
#
#        AccountName_5e02b1554bfe4b0dac61f801SenPol  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 40449                                         NaN
# 40450                                         NaN
# 40451                                         NaN
# 40452                                         NaN
# 40453                                         NaN
#
#        AccountName_5e02b1554bfe4b0dac61f801SenScore   BPCode COVIDComments  \
# 0                                               NaN  2436605          None
# 1                                               NaN  1982215          None
# 2                                               NaN  1725203          None
# 3                                               NaN  1677275          None
# 4                                               NaN  2217778          None
# ...                                             ...      ...           ...
# 40449                                           NaN  1504454          None
# 40450                                           NaN   341912          None
# 40451                                           NaN  2463853          None
# 40452                                           NaN   859188          None
# 40453                                           NaN  2196616          None
#
#                                                  CRMLink           CRMOwner  \
# 0      https://dowchemical.crm.dynamics.com/main.aspx...       Kevin Pillay
# 1                                                   None         Sven Petri
# 2                                                   None       Dicle Gunbay
# 3                                                   None         Kaya Akyuz
# 4                                                   None               None
# ...                                                  ...                ...
# 40449  https://dowchemical.crm.dynamics.com/main.aspx...        Zafar Iqbal
# 40450  https://dowchemical.crm.dynamics.com/main.aspx...      Sandy Tavares
# 40451  https://dowchemical.crm.dynamics.com/main.aspx...  Vincenzo Pennetta
# 40452  https://dowchemical.crm.dynamics.com/main.aspx...        Carvin TENG
# 40453  https://dowchemical.crm.dynamics.com/main.aspx...    Gaetano Di Maio
#
#            CRMOwnerEmail ContactArea ContactAreaCode  ... progress  \
# 0                   None       EMEAI               1  ...      100
# 1                   None       EMEAI               1  ...      100
# 2                   None       EMEAI               1  ...      100
# 3                   None       EMEAI               1  ...      100
# 4                   None       EMEAI               1  ...        3
# ...                  ...         ...             ...  ...      ...
# 40449     ZIqbal@dow.com       EMEAI               1  ...      100
# 40450  sftavares@dow.com         LAA               3  ...      100
# 40451  VPennetta@dow.com       EMEAI               1  ...      100
# 40452   c.c.teng@dow.com        APAC               2  ...      100
# 40453    GDiMaio@dow.com       EMEAI               1  ...       33
#
#                            recipientEmail  recipientFirstName  \
# 0        christiaan.vanrooyen@abengoa.com  Christiaan Rudolph
# 1              didier.woerther@benvic.com              Didier
# 2        nurselkizilkan@ecoplast-film.com              Nursel
# 3      mustafa.kirmizi@entegreharc.com.tr             Mustafa
# 4         katarzyna.pluciennik@arpanel.pl           Katarzyna
# ...                                   ...                 ...
# 40449          fredrik.calenius@teknos.fi             Fredrik
# 40450          jgiraldo@microplast.com.co               James
# 40451              junmei_zhu@eu.irco.com              Junmei
# 40452            lovemin0607@yahoo.com.tw                Ryan
# 40453          JANNI.THOMASEN@CEMBRIT.COM               Janni
#
#       recipientLastName              recordedDate         responseId  \
# 0            van Rooyen  2021-07-24T11:17:26.019Z  R_003olKHEbIQa2fI
# 1                  None  2021-07-24T11:17:14.910Z  R_008TKF0DV29r6Mm
# 2                  None  2021-07-24T11:17:36.965Z  R_00wicD2aXNMUV9k
# 3               Kirmizi  2021-07-24T11:17:45.947Z  R_01ayXljDgiXbAIS
# 4                  None  2021-07-24T11:17:47.761Z  R_021bboTA4DY9Tn0
# ...                 ...                       ...                ...
# 40449          Calenius  2023-05-12T07:01:40.229Z  R_yqJKSkzBwcsbEqJ
# 40450           Giraldo  2022-05-20T14:55:20.088Z  R_ysVTohnHumYvcyd
# 40451               Zhu  2022-05-26T12:54:39.555Z  R_z72GF0PEHdwduq5
# 40452              Tsai  2022-11-08T07:39:14.281Z  R_zVE8IrrL0u19Rh7
# 40453          Thomasen  2022-09-12T08:48:01.003Z  R_zbPPpuSeMiYb7hv
#
#                       startDate status status_label userLanguage
# 0      2021-07-24T11:17:25.993Z      4     Imported           EN
# 1      2021-07-24T11:17:14.905Z      4     Imported           FR
# 2      2021-07-24T11:17:36.949Z      4     Imported           TR
# 3      2021-07-24T11:17:45.905Z      4     Imported           TR
# 4      2021-07-24T11:17:47.751Z      4     Imported           PL
# ...                         ...    ...          ...          ...
# 40449      2023-05-12T06:58:42Z      0   IP Address           EN
# 40450      2022-05-20T14:43:10Z      0   IP Address           ES
# 40451      2022-05-26T12:44:41Z      0   IP Address           EN
# 40452      2022-11-08T07:36:47Z      0   IP Address         ZH-T
# 40453      2022-09-01T07:13:14Z      0   IP Address           EN
#
# [40454 rows x 391 columns]
